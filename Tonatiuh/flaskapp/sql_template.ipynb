# %%
import sqlite3
import jinja2
from IPython.core.display import display, HTML
from flask import Flask, request, g
from flask import render_template

conn = sqlite3.connect('Wikipedia-lsi.db')
c = conn.cursor()

from ast import literal_eval

# %%
c.row_factory = sqlite3.Row
rows = c.execute('select * from Wikipedia').fetchall()


template_string = """   {% for row in rows %}
        {{row['id']}}, <b>{{row['title']}}</b>,
        <url>{{row['url']}}</url><br>
        {% set other_titles = row['other_titles'].replace(']','').replace('[','').split(',') %}
        {% for other in other_titles%}
        <tr>{{other}}</tr><br>
        {% endfor %}
        <br>
    {% endfor %}"""

# %%
template = jinja2.Template(template_string)
#result = template.render(rows=rows)
result = template.render(rows=rows)


display(HTML(result))
# Out:
#
#         1467938, <b>Kennel</b>,
#         <url>https://en.wikipedia.org/wiki/Kennel</url><br>
#
#
#         <tr>'Cattery'</tr><br>
#
#         <tr> 'Indian National Kennel Club'</tr><br>
#
#         <tr> 'Breed type (dog)'</tr><br>
#
#         <tr> 'Dog World (newspaper)'</tr><br>
#
#         <tr> 'Lists of dogs'</tr><br>
#
#         <br>
#
#         275388, <b>Cynology</b>,
#         <url>https://en.wikipedia.org/wiki/Cynology</url><br>
#
#
#         <tr>'Dog'</tr><br>
#
#         <tr> 'Breed type (dog)'</tr><br>
#
#         <tr> 'Dog World (newspaper)'</tr><br>
#
#         <tr> 'Cat training'</tr><br>
#
#         <tr> 'Dog bite'</tr><br>
#
#         <br>
#
#         2352562, <b>Pack (canine)</b>,
#         <url>https://en.wikipedia.org/wiki/Pack_(canine)</url><br>
#
#
#         <tr>'Canid hybrid'</tr><br>
#
#         <tr> 'Dog'</tr><br>
#
#         <tr> 'Origin of the domestic dog'</tr><br>
#
#         <tr> 'Canine reproduction'</tr><br>
#
#         <tr> 'Dog bite'</tr><br>
#
#         <br>
#
#         17021807, <b>Rare breed (dog)</b>,
#         <url>https://en.wikipedia.org/wiki/Rare_breed_(dog)</url><br>
#
#
#         <tr>'Breed type (dog)'</tr><br>
#
#         <tr> 'Lists of dogs'</tr><br>
#
#         <tr> 'Dog'</tr><br>
#
#         <tr> 'Dog bite'</tr><br>
#
#         <tr> 'Origin of the domestic dog'</tr><br>
#
#         <br>
#
#         20777185, <b>Dogs in ancient China</b>,
#         <url>https://en.wikipedia.org/wiki/Dogs_in_ancient_China</url><br>
#
#
#         <tr>'Dog'</tr><br>
#
#         <tr> 'Dogs in Mesoamerica'</tr><br>
#
#         <tr> 'Origin of the domestic dog'</tr><br>
#
#         <tr> 'Dog meat'</tr><br>
#
#         <tr> 'Dogs in religion'</tr><br>
#
#         <br>
#
#         4020758, <b>Dog biscuit</b>,
#         <url>https://en.wikipedia.org/wiki/Dog_biscuit</url><br>
#
#
#         <tr>'Dog food'</tr><br>
#
#         <tr> 'Dog meat'</tr><br>
#
#         <tr> 'Dog daycare'</tr><br>
#
#         <tr> 'Cat meat'</tr><br>
#
#         <tr> 'Dog'</tr><br>
#
#         <br>
#
#         17430047, <b>Breed type (dog)</b>,
#         <url>https://en.wikipedia.org/wiki/Breed_type_(dog)</url><br>
#
#
#         <tr>'Rare breed (dog)'</tr><br>
#
#         <tr> 'Dog World (newspaper)'</tr><br>
#
#         <tr> 'Indian National Kennel Club'</tr><br>
#
#         <tr> 'Dog'</tr><br>
#
#         <tr> 'Lists of dogs'</tr><br>
#
#         <br>
#
#         2676271, <b>Canid hybrid</b>,
#         <url>https://en.wikipedia.org/wiki/Canid_hybrid</url><br>
#
#
#         <tr>'Origin of the domestic dog'</tr><br>
#
#         <tr> 'Dog'</tr><br>
#
#         <tr> 'Interbreeding of dingoes with other domestic dogs'</tr><br>
#
#         <tr> 'Pack (canine)'</tr><br>
#
#         <tr> 'Canine reproduction'</tr><br>
#
#         <br>
#
#         22044074, <b>Canine physical therapy</b>,
#         <url>https://en.wikipedia.org/wiki/Canine_physical_therapy</url><br>
#
#
#         <tr>'Therapy cat'</tr><br>
#
#         <tr> 'Cynophobia'</tr><br>
#
#         <tr> 'Human–canine bond'</tr><br>
#
#         <tr> 'Cat anatomy'</tr><br>
#
#         <tr> 'Dog'</tr><br>
#
#         <br>
#
#         19282291, <b>Dogs in Mesoamerica</b>,
#         <url>https://en.wikipedia.org/wiki/Dogs_in_Mesoamerica</url><br>
#
#
#         <tr>'Dogs in ancient China'</tr><br>
#
#         <tr> 'Dog'</tr><br>
#
#         <tr> 'Dogs in religion'</tr><br>
#
#         <tr> 'Dog meat'</tr><br>
#
#         <tr> 'Origin of the domestic dog'</tr><br>
#
#         <br>
#
#         23416702, <b>Interbreeding of dingoes with other domestic dogs</b>,
#         <url>https://en.wikipedia.org/wiki/Interbreeding_of_dingoes_with_other_domestic_dogs</url><br>
#
#
#         <tr>'Canid hybrid'</tr><br>
#
#         <tr> 'Dog'</tr><br>
#
#         <tr> 'Origin of the domestic dog'</tr><br>
#
#         <tr> 'Cat'</tr><br>
#
#         <tr> 'Feral cat'</tr><br>
#
#         <br>
#
#         5740890, <b>Canine reproduction</b>,
#         <url>https://en.wikipedia.org/wiki/Canine_reproduction</url><br>
#
#
#         <tr>'Dog'</tr><br>
#
#         <tr> 'Cat'</tr><br>
#
#         <tr> 'Origin of the domestic dog'</tr><br>
#
#         <tr> 'Human interaction with cats'</tr><br>
#
#         <tr> 'Canid hybrid'</tr><br>
#
#         <br>
#
#         31752133, <b>PDSA Certificate for Animal Bravery or Devotion</b>,
#         <url>https://en.wikipedia.org/wiki/PDSA_Certificate_for_Animal_Bravery_or_Devotion</url><br>
#
#
#         <tr>'Dog World (newspaper)'</tr><br>
#
#         <tr> 'Dog'</tr><br>
#
#         <tr> 'Dog meat'</tr><br>
#
#         <tr> 'Dog bite'</tr><br>
#
#         <tr> 'Dog bite prevention'</tr><br>
#
#         <br>
#
#         33069847, <b>Cropping (animal)</b>,
#         <url>https://en.wikipedia.org/wiki/Cropping_(animal)</url><br>
#
#
#         <tr>'Puppy'</tr><br>
#
#         <tr> 'Dog'</tr><br>
#
#         <tr> 'Dog bite'</tr><br>
#
#         <tr> 'Cat'</tr><br>
#
#         <tr> 'Body language of dogs'</tr><br>
#
#         <br>
#
#         32912733, <b>Pet Check Technology</b>,
#         <url>https://en.wikipedia.org/wiki/Pet_Check_Technology</url><br>
#
#
#         <tr>'Pet Fed India'</tr><br>
#
#         <tr> 'Dog'</tr><br>
#
#         <tr> 'Dog food'</tr><br>
#
#         <tr> 'Dog daycare'</tr><br>
#
#         <tr> 'Dog bite'</tr><br>
#
#         <br>
#
#         24243398, <b>Dog daycare</b>,
#         <url>https://en.wikipedia.org/wiki/Dog_daycare</url><br>
#
#
#         <tr>'Dog'</tr><br>
#
#         <tr> 'Dog meat'</tr><br>
#
#         <tr> 'International Cat Day'</tr><br>
#
#         <tr> 'Dog World (newspaper)'</tr><br>
#
#         <tr> 'Dog biscuit'</tr><br>
#
#         <br>
#
#         17862013, <b>Dogs in religion</b>,
#         <url>https://en.wikipedia.org/wiki/Dogs_in_religion</url><br>
#
#
#         <tr>'Dog'</tr><br>
#
#         <tr> 'Dogs in ancient China'</tr><br>
#
#         <tr> 'Dogs in Mesoamerica'</tr><br>
#
#         <tr> 'Cats in ancient Egypt'</tr><br>
#
#         <tr> 'Panhu'</tr><br>
#
#         <br>
#
#         34442389, <b>The Ten Commandments of Dog Ownership</b>,
#         <url>https://en.wikipedia.org/wiki/The_Ten_Commandments_of_Dog_Ownership</url><br>
#
#
#         <tr>'The Dog Pillow'</tr><br>
#
#         <tr> 'Walter the Farting Dog'</tr><br>
#
#         <tr> 'Dog'</tr><br>
#
#         <tr> 'Dog World (newspaper)'</tr><br>
#
#         <tr> 'Dog meat'</tr><br>
#
#         <br>
#
#         178449, <b>Roan (color)</b>,
#         <url>https://en.wikipedia.org/wiki/Roan_(color)</url><br>
#
#
#         <tr>'Cat coat genetics'</tr><br>
#
#         <tr> 'Point coloration'</tr><br>
#
#         <tr> 'Deaf white cat'</tr><br>
#
#         <tr> 'Dog'</tr><br>
#
#         <tr> 'Cat'</tr><br>
#
#         <br>
#
#         36477294, <b>Panhu</b>,
#         <url>https://en.wikipedia.org/wiki/Panhu</url><br>
#
#
#         <tr>'Dogs in religion'</tr><br>
#
#         <tr> 'Dogs in ancient China'</tr><br>
#
#         <tr> 'Lychee and Dog Meat Festival'</tr><br>
#
#         <tr> 'Dog meat'</tr><br>
#
#         <tr> 'Cultural depictions of cats'</tr><br>
#
#         <br>
#
#         31804256, <b>The Dog Pillow</b>,
#         <url>https://en.wikipedia.org/wiki/The_Dog_Pillow</url><br>
#
#
#         <tr>'The Ten Commandments of Dog Ownership'</tr><br>
