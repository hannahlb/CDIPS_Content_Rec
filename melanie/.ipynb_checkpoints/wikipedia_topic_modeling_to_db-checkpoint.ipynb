# %% [markdown]
# Modified from: wikipedia_topic_modeling notebook
#
# For each model, create a database with columns: (1) article title, (2) url, (3) list of similar articles, (4) list of urls for similar articles, (5) list of similarity scores
#
# These databases will be queried in the web application
#
# Use default num_topics

# %%
import sys, os
from xml.dom import minidom
import nltk
import pandas as pd

from collections import defaultdict
from gensim import corpora, models, similarities
# Out:
# C:\Users\melanie\Anaconda3\envs\cdips2017\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
os.chdir('..\data')

# %%
def get_page_type(title):
    """
    from WikiPage.py: extract page type from article title
    """
    if 'Category:' in title:
        return 'category'
    elif 'Portal:' in title:
        return 'portal'
    elif 'List of' in title:
        return 'list'
    elif 'File:' in title:
        return 'file'
    else:
        return 'article'

def xml_to_df(xmlfile):
    """
    input: xml filename
    output: data frame with columns: article id, title, url, page_type, tokenized text
    
    filter out pages that are not articles
    """
    xmldoc = minidom.parse(xmlfile)
    idlist = xmldoc.getElementsByTagName('id')
    titlelist = xmldoc.getElementsByTagName('title')
    textlist = xmldoc.getElementsByTagName('text')
    
    titles = [title.childNodes[0].data for title in titlelist]
    urllist = ['https://en.wikipedia.org/wiki/%s' % (title.replace(' ', '_'))
              for title in titles]
    typelist = [get_page_type(title) for title in titles]
    
    tokenizer = nltk.RegexpTokenizer(r'\w+')
    
    word_data = [(id.childNodes[0].data, title, url, page_type,
                  tokenizer.tokenize(text.childNodes[0].data.lower()))
                for id, title, url, page_type, text in zip(idlist, titles, urllist, typelist, textlist)
                if page_type == 'article']
    word_data_df = pd.DataFrame(word_data, columns=['id', 'title', 'url', 'type', 'words'])
    #word_data_df.to_csv('word_data_df.csv')
    return(word_data_df)

# %%
xmlfile = 'Wikipedia-dog.xml'
df1 = xml_to_df(xmlfile)
#xmlfile = 'Wikipedia-fish.xml'
#df2 = xml_to_df(xmlfile)
word_data_df = df1 #.append(df2)
#word_data_df.head()

# %%
word_data_df
# Out:
#            id                                              title  \
# 0     5957048                                             Kennel
# 1      729436                                           Cynology
# 2     1764821                                      Pack (canine)
# 3   547372987                                   Rare breed (dog)
# 4   547375119                              Dogs in ancient China
# 5     6569922                                        Dog biscuit
# 6   747942371                                   Breed type (dog)
# 7     1467938                                       Canid hybrid
# 8   772563016                            Canine physical therapy
# 9    13286072                                Dogs in Mesoamerica
# 10     275388  Interbreeding of dingoes with other domestic dogs
# 11  773697329                                Canine reproduction
# 12   13286072    PDSA Certificate for Animal Bravery or Devotion
# 13  693299905                                  Cropping (animal)
# 14   25152539                               Pet Check Technology
# 15    1968414                                        Dog daycare
# 16  144853393                                   Dogs in religion
# 17    1777080              The Ten Commandments of Dog Ownership
# 18  740619279                                       Roan (color)
# 19   22066013                                              Panhu
# 20     691500                                     The Dog Pillow
# 21  790195106                           Queen Elizabeth's corgis
# 22    1879566                              Dog World (newspaper)
# 23    2352562                         Origin of the domestic dog
# 24   17021807                                         Cynophobia
# 25  762623658                             Walter the Farting Dog
# 26  548518791                           Puppy pregnancy syndrome
# 27     259798                                  Human–canine bond
# 28  604361169                                            Mastiff
# 29    4635357                               My Life in Dog Years
# ..        ...                                                ...
# 64    1396693                                         Felinology
# 65  762378101                                            Fel d 1
# 66   25152539                                        Cat-burning
# 67   36477294                        Human interaction with cats
# 68  790628362                                 Operation Cat Drop
# 69   31804256                                          Feral cat
# 70  707351424                                              Pussy
# 71  786125886                                        Cat anatomy
# 72  790817933                                           Cat café
# 73     119438                                  Cat coat genetics
# 74     693519                Pinch-induced behavioral inhibition
# 75  546468781                                           Pink cat
# 76   14393296                                           Cat meat
# 77    9369613                                Crumbs and Whiskers
# 78  785427477                                     Hermitage cats
# 79     158914                                        Therapy cat
# 80   10579085                          Cat predation on wildlife
# 81   30707369                                  Koneko (cat cafe)
# 82   20444317                             Purringtons Cat Lounge
# 83  779849768                                            Cat gap
# 84   20846898                             Exotic felines as pets
# 85   38928070                              Cats in ancient Egypt
# 86  780421858                                         Cat senses
# 87    4968133                                   Point coloration
# 88   31903693                                    Feline zoonosis
# 89  787653468                                                Cat
# 90   41493138                                           Cat bite
# 91  701109732                             Ancylostoma tubaeforme
# 92     754619                                    Feline diseases
# 93     849619                              International Cat Day
#
#                                                   url     type  \
# 0                https://en.wikipedia.org/wiki/Kennel  article
# 1              https://en.wikipedia.org/wiki/Cynology  article
# 2         https://en.wikipedia.org/wiki/Pack_(canine)  article
# 3      https://en.wikipedia.org/wiki/Rare_breed_(dog)  article
# 4   https://en.wikipedia.org/wiki/Dogs_in_ancient_...  article
# 5           https://en.wikipedia.org/wiki/Dog_biscuit  article
# 6      https://en.wikipedia.org/wiki/Breed_type_(dog)  article
# 7          https://en.wikipedia.org/wiki/Canid_hybrid  article
# 8   https://en.wikipedia.org/wiki/Canine_physical_...  article
# 9   https://en.wikipedia.org/wiki/Dogs_in_Mesoamerica  article
# 10  https://en.wikipedia.org/wiki/Interbreeding_of...  article
# 11  https://en.wikipedia.org/wiki/Canine_reproduction  article
# 12  https://en.wikipedia.org/wiki/PDSA_Certificate...  article
# 13    https://en.wikipedia.org/wiki/Cropping_(animal)  article
# 14  https://en.wikipedia.org/wiki/Pet_Check_Techno...  article
# 15          https://en.wikipedia.org/wiki/Dog_daycare  article
# 16     https://en.wikipedia.org/wiki/Dogs_in_religion  article
# 17  https://en.wikipedia.org/wiki/The_Ten_Commandm...  article
# 18         https://en.wikipedia.org/wiki/Roan_(color)  article
# 19                https://en.wikipedia.org/wiki/Panhu  article
# 20       https://en.wikipedia.org/wiki/The_Dog_Pillow  article
# 21  https://en.wikipedia.org/wiki/Queen_Elizabeth'...  article
# 22  https://en.wikipedia.org/wiki/Dog_World_(newsp...  article
# 23  https://en.wikipedia.org/wiki/Origin_of_the_do...  article
# 24           https://en.wikipedia.org/wiki/Cynophobia  article
# 25  https://en.wikipedia.org/wiki/Walter_the_Farti...  article
# 26  https://en.wikipedia.org/wiki/Puppy_pregnancy_...  article
# 27    https://en.wikipedia.org/wiki/Human–canine_bond  article
# 28              https://en.wikipedia.org/wiki/Mastiff  article
# 29  https://en.wikipedia.org/wiki/My_Life_in_Dog_Y...  article
# ..                                                ...      ...
# 64           https://en.wikipedia.org/wiki/Felinology  article
# 65              https://en.wikipedia.org/wiki/Fel_d_1  article
# 66          https://en.wikipedia.org/wiki/Cat-burning  article
# 67  https://en.wikipedia.org/wiki/Human_interactio...  article
# 68   https://en.wikipedia.org/wiki/Operation_Cat_Drop  article
# 69            https://en.wikipedia.org/wiki/Feral_cat  article
# 70                https://en.wikipedia.org/wiki/Pussy  article
# 71          https://en.wikipedia.org/wiki/Cat_anatomy  article
# 72             https://en.wikipedia.org/wiki/Cat_café  article
# 73    https://en.wikipedia.org/wiki/Cat_coat_genetics  article
# 74  https://en.wikipedia.org/wiki/Pinch-induced_be...  article
# 75             https://en.wikipedia.org/wiki/Pink_cat  article
# 76             https://en.wikipedia.org/wiki/Cat_meat  article
# 77  https://en.wikipedia.org/wiki/Crumbs_and_Whiskers  article
# 78       https://en.wikipedia.org/wiki/Hermitage_cats  article
# 79          https://en.wikipedia.org/wiki/Therapy_cat  article
# 80  https://en.wikipedia.org/wiki/Cat_predation_on...  article
# 81    https://en.wikipedia.org/wiki/Koneko_(cat_cafe)  article
# 82  https://en.wikipedia.org/wiki/Purringtons_Cat_...  article
# 83              https://en.wikipedia.org/wiki/Cat_gap  article
# 84  https://en.wikipedia.org/wiki/Exotic_felines_a...  article
# 85  https://en.wikipedia.org/wiki/Cats_in_ancient_...  article
# 86           https://en.wikipedia.org/wiki/Cat_senses  article
# 87     https://en.wikipedia.org/wiki/Point_coloration  article
# 88      https://en.wikipedia.org/wiki/Feline_zoonosis  article
# 89                  https://en.wikipedia.org/wiki/Cat  article
# 90             https://en.wikipedia.org/wiki/Cat_bite  article
# 91  https://en.wikipedia.org/wiki/Ancylostoma_tuba...  article
# 92      https://en.wikipedia.org/wiki/Feline_diseases  article
# 93  https://en.wikipedia.org/wiki/International_Ca...  article
#
#                                                 words
# 0   [about, shelter, for, dogs, and, cats, for, th...
# 1   [cynology, ipac, en, s, ᵻ, ˈ, n, ɒ, l, ə, dʒ, ...
# 2   [other, uses, wolfpack, disambiguation, image,...
# 3   [for, a, list, of, rare, dog, breeds, category...
# 4   [refimprove, date, december, 2008, originalres...
# 5   [image, dog, biscuit, jpg, thumb, right, a, do...
# 6   [use, dmy, dates, date, july, 2013, breed, typ...
# 7   [redirect2, dog, hybrid, hybrid, dog, all, dom...
# 8   [infobox, disease, name, canine, physical, the...
# 9   [no, footnotes, date, april, 2009, various, so...
# 10  [use, dmy, dates, date, december, 2012, file, ...
# 11  [about, reproduction, in, domestic, dogs, repr...
# 12  [infobox, award, name, pdsa, certificate, for,...
# 13  [about, the, partial, removal, of, the, ears, ...
# 14  [orphan, date, january, 2013, pet, check, tech...
# 15  [use, dmy, dates, date, may, 2013, file, runni...
# 16  [file, dog, worship, in, hinduism, jpg, thumb,...
# 17  [the, ten, commandments, of, dog, ownership, a...
# 18  [other, uses, roan, disambiguation, roan, refi...
# 19  [panhu, 盤瓠, ipa, pǎn, hǔ, is, an, important, f...
# 20  [italic, title, inu, makura, or, nihongo, the,...
# 21  [file, queen, mother, with, corgis, jpg, thumb...
# 22  [use, dmy, dates, date, october, 2015, use, br...
# 23  [pp, semi, indef, file, canis, lupus, howling,...
# 24  [distinguish, sinophobia, infobox, medical, co...
# 25  [walter, the, farting, dog, is, the, title, ch...
# 26  [puppy, pregnancy, syndrome, is, a, psychosoma...
# 27  [file, the, human, canine, bond, is, so, touch...
# 28  [other, uses, distinguish, massif, file, 11m, ...
# 29  [infobox, book, see, wikipedia, wikiproject_no...
# ..                                                ...
# 64  [file, fetuses, of, two, cats, fmvz, usp, 01, ...
# 65  [infobox, protein, name, major, allergen, i, p...
# 66  [cat, burning, was, a, form, of, zoosadism, zo...
# 67  [use, dmy, dates, date, november, 2013, file, ...
# 68  [one, source, date, september, 2014, operation...
# 69  [lead, too, short, date, december, 2016, use, ...
# 70  [about, the, word, sprotected, small, yes, pp,...
# 71  [file, meyer, zeit, vertreib, 1, tafel, 015, j...
# 72  [lead, too, short, date, april, 2016, use, dmy...
# 73  [file, cat, blending, in, jpg, thumb, 250px, t...
# 74  [multiple, issues, orphan, date, january, 2015...
# 75  [file, chat, rose, du, gard, jpg, thumb, a, pi...
# 76  [for, meat, eaten, by, cats, cat, food, file, ...
# 77  [use, mdy, dates, date, january, 2017, infobox...
# 78  [file, hermitage, cat, jpeg, thumb, one, of, t...
# 79  [medref, date, december, 2015, file, unitarian...
# 80  [cat, s, hunt, small, prey, and, both, feral, ...
# 81  [orphan, date, march, 2016, file, koneko, exte...
# 82  [purringtons, cat, lounge, sometimes, purringt...
# 83  [the, cat, gap, is, a, period, in, the, fossil...
# 84  [orphan, date, september, 2016, merge, to, fel...
# 85  [multiple, issues, more, footnotes, date, octo...
# 86  [use, dmy, dates, date, july, 2013, refimprove...
# 87  [one, source, date, may, 2009, image, neighbou...
# 88  [infobox, medical, condition, name, feline, zo...
# 89  [about, the, cat, species, that, is, commonly,...
# 90  [infobox, disease, name, cat, bite, image, cat...
# 91  [italic, title, taxobox, image, name, ancylost...
# 92  [further, feline, zoonosis, see, cat, health, ...
# 93  [infobox, holiday, holiday_name, international...
#
# [94 rows x 5 columns]

# %%
def make_dictionary(documents):
    """
    construct a dictionary, i.e. mapping btwn word ids and their freq of occurence in the whole corpus
    filter dictionary to remove stopwords and words occuring < min_count times
    
    input: documents is an iterable consisting of all the words in the corpus 
    output: filtered dictionary
    """
    dictionary = corpora.Dictionary(documents)

    stop_words = nltk.corpus.stopwords.words('english') 
    min_count = 2
    stop_ids = [dictionary.token2id[word] for word in stop_words
               if word in dictionary.token2id]
    rare_ids = [id for id, freq in dictionary.dfs.items()
                if freq < min_count]
    dictionary.filter_tokens(stop_ids + rare_ids)
    dictionary.compactify()
    return(dictionary)

def make_corpus(word_data_df):
    """
    """
    documents = word_data_df['words'].values
    dictionary = make_dictionary(documents)
    # convert corpus to vectors using bag-of-words representation, i.e. tuples of word indices and word counts
    corpus = [dictionary.doc2bow(words) for words in documents]
    return(corpus, dictionary)

def make_lsi_similarity_matrix(word_data_df, tfidf_corpus, dictionary):
    """
    construct LSI (latent semantic indexing) model on Tfidf-transformed corpus, print model topics, 
    return similarity matrix.
    """
    # construct model
    lsi = models.lsimodel.LsiModel(tfidf_corpus, id2word=dictionary, num_topics=200) 
    lsi.save('wiki.lsi')
    for i, topic in enumerate(lsi.print_topics(5)[:3]):
        print('Topic: ', format(i))
        print(str(topic).replace(' + ', '\n')) 
        print('') 
    # create similarity matrix
    matsim = similarities.MatrixSimilarity(lsi[tfidf_corpus], num_best=6)
    
    titles = word_data_df['title']
    urls = word_data_df['url']
    # from Tonatiuh's similarity_matrix.py: save output in similarity_matrix array
    similarity_matrix = defaultdict(list)
    for title, url, sims in zip(titles, urls, matsim):
        similarity_matrix[title].append([]) # list of titles
        similarity_matrix[title].append([]) # list of urls
        similarity_matrix[title].append([]) # list of similar article titles
        similarity_matrix[title].append([]) # list of similar article urls
        similarity_matrix[title].append([]) # list of similar article scores
        similarity_matrix[title][0].append(title)
        similarity_matrix[title][1].append(url)
        for other_title_index, score in sims[1:]:
            similarity_matrix[title][2].append(titles[other_title_index])
            similarity_matrix[title][3].append(urls[other_title_index])
            similarity_matrix[title][4].append(score)    
    return(similarity_matrix, matsim)

def print_similar_articles(word_data_df, matsim, num_print):
    """http://localhost:8888/notebooks/CDIPS_Content_Rec/melanie/wikipedia_topic_modeling_to_db.ipynb#
    print titles of first num_print articles and their most similar articles and similarity scores.
    this is independent of model used.
    """
    titles = word_data_df['title']
    # for the first num_print articles, print most similar articles and their similarity scores
    for sims in list(matsim)[:num_print]:
        title_index = sims[0][0]
        print(titles[title_index]) 
        for other_title_index, score in sims[1:]:
            print('\t', titles[other_title_index], ' ', score)

# %%
corpus, dictionary = make_corpus(word_data_df)
tfidf = models.TfidfModel(corpus)
lsi_similarity_matrix,lsi_matsim = make_lsi_similarity_matrix(word_data_df, tfidf[corpus], dictionary)
# Out:
# Topic:  0
# (0, '0.301*"cat"
# 0.219*"cats"
# 0.192*"dog"
# 0.155*"journal"
# 0.115*"meat"
# 0.094*"name"
# 0.091*"dogs"
# 0.090*"feral"
# 0.090*"doi"
# 0.089*"volume"')
#
# Topic:  1
# (1, '-0.415*"cat"
# -0.345*"cafe"
# 0.316*"dog"
# -0.250*"cats"
# -0.138*"café"
# 0.132*"dogs"
# 0.130*"breed"
# 0.111*"wagging"
# 0.111*"kennel"
# 0.104*"breeds"')
#
# Topic:  2
# (2, '-0.273*"meat"
# 0.253*"bites"
# -0.224*"cafe"
# 0.222*"bite"
# 0.173*"rabies"
# 0.161*"cdc"
# -0.144*"festival"
# -0.135*"china"
# 0.127*"infection"
# 0.114*"wagging"')

# %%
lsi_similarity_matrix
# Out:
# defaultdict(list,
#             {'Ailurophobia': [['Ailurophobia',
#                'Ailurophobia',
#                'Ailurophobia',
#                'Ailurophobia',
#                'Ailurophobia'],
#               ['https://en.wikipedia.org/wiki/Ailurophobia',
#                'https://en.wikipedia.org/wiki/Ailurophobia',
#                'https://en.wikipedia.org/wiki/Ailurophobia',
#                'https://en.wikipedia.org/wiki/Ailurophobia',
#                'https://en.wikipedia.org/wiki/Ailurophobia'],
#               ['Cynophobia',
#                'Cat',
#                'Human interaction with cats',
#                'Cat senses',
#                'Dog'],
#               ['https://en.wikipedia.org/wiki/Cynophobia',
#                'https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Human_interaction_with_cats',
#                'https://en.wikipedia.org/wiki/Cat_senses',
#                'https://en.wikipedia.org/wiki/Dog'],
#               [0.30192595720291138,
#                0.20404037833213806,
#                0.14969448745250702,
#                0.12394128739833832,
#                0.11834602802991867]],
#              'Ancylostoma tubaeforme': [['Ancylostoma tubaeforme',
#                'Ancylostoma tubaeforme',
#                'Ancylostoma tubaeforme',
#                'Ancylostoma tubaeforme',
#                'Ancylostoma tubaeforme'],
#               ['https://en.wikipedia.org/wiki/Ancylostoma_tubaeforme',
#                'https://en.wikipedia.org/wiki/Ancylostoma_tubaeforme',
#                'https://en.wikipedia.org/wiki/Ancylostoma_tubaeforme',
#                'https://en.wikipedia.org/wiki/Ancylostoma_tubaeforme',
#                'https://en.wikipedia.org/wiki/Ancylostoma_tubaeforme'],
#               ['Cat bite',
#                'Feline zoonosis',
#                'Cat',
#                'Feline diseases',
#                'Cat predation on wildlife'],
#               ['https://en.wikipedia.org/wiki/Cat_bite',
#                'https://en.wikipedia.org/wiki/Feline_zoonosis',
#                'https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Feline_diseases',
#                'https://en.wikipedia.org/wiki/Cat_predation_on_wildlife'],
#               [0.14123387634754181,
#                0.080228425562381744,
#                0.060580160468816757,
#                0.055692229419946671,
#                0.05561433732509613]],
#              'Becerrillo': [['Becerrillo',
#                'Becerrillo',
#                'Becerrillo',
#                'Becerrillo',
#                'Becerrillo'],
#               ['https://en.wikipedia.org/wiki/Becerrillo',
#                'https://en.wikipedia.org/wiki/Becerrillo',
#                'https://en.wikipedia.org/wiki/Becerrillo',
#                'https://en.wikipedia.org/wiki/Becerrillo',
#                'https://en.wikipedia.org/wiki/Becerrillo'],
#               ['Dog',
#                'Rare breed (dog)',
#                'Dog meat',
#                'Canine reproduction',
#                'Cat'],
#               ['https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Rare_breed_(dog)',
#                'https://en.wikipedia.org/wiki/Dog_meat',
#                'https://en.wikipedia.org/wiki/Canine_reproduction',
#                'https://en.wikipedia.org/wiki/Cat'],
#               [0.087961174547672272,
#                0.070747636258602142,
#                0.064921654760837555,
#                0.062798939645290375,
#                0.061508245766162872]],
#              'Body language of dogs': [['Body language of dogs',
#                'Body language of dogs',
#                'Body language of dogs',
#                'Body language of dogs',
#                'Body language of dogs'],
#               ['https://en.wikipedia.org/wiki/Body_language_of_dogs',
#                'https://en.wikipedia.org/wiki/Body_language_of_dogs',
#                'https://en.wikipedia.org/wiki/Body_language_of_dogs',
#                'https://en.wikipedia.org/wiki/Body_language_of_dogs',
#                'https://en.wikipedia.org/wiki/Body_language_of_dogs'],
#               ['Tail wagging by dogs',
#                'Dog bite prevention',
#                'Dog bite',
#                'Dog',
#                'Cat'],
#               ['https://en.wikipedia.org/wiki/Tail_wagging_by_dogs',
#                'https://en.wikipedia.org/wiki/Dog_bite_prevention',
#                'https://en.wikipedia.org/wiki/Dog_bite',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Cat'],
#               [0.60040205717086792,
#                0.37101003527641296,
#                0.1758030503988266,
#                0.1177382618188858,
#                0.082366533577442169]],
#              'Bog Dog': [['Bog Dog',
#                'Bog Dog',
#                'Bog Dog',
#                'Bog Dog',
#                'Bog Dog'],
#               ['https://en.wikipedia.org/wiki/Bog_Dog',
#                'https://en.wikipedia.org/wiki/Bog_Dog',
#                'https://en.wikipedia.org/wiki/Bog_Dog',
#                'https://en.wikipedia.org/wiki/Bog_Dog',
#                'https://en.wikipedia.org/wiki/Bog_Dog'],
#               ['Rolfi',
#                'Lists of dogs',
#                'Cats in ancient Egypt',
#                'Dog',
#                'Dog bite'],
#               ['https://en.wikipedia.org/wiki/Rolfi',
#                'https://en.wikipedia.org/wiki/Lists_of_dogs',
#                'https://en.wikipedia.org/wiki/Cats_in_ancient_Egypt',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Dog_bite'],
#               [0.40277498960494995,
#                0.1552005261182785,
#                0.10076527297496796,
#                0.028615597635507584,
#                0.028530003502964973]],
#              'Breed type (dog)': [['Breed type (dog)',
#                'Breed type (dog)',
#                'Breed type (dog)',
#                'Breed type (dog)',
#                'Breed type (dog)'],
#               ['https://en.wikipedia.org/wiki/Breed_type_(dog)',
#                'https://en.wikipedia.org/wiki/Breed_type_(dog)',
#                'https://en.wikipedia.org/wiki/Breed_type_(dog)',
#                'https://en.wikipedia.org/wiki/Breed_type_(dog)',
#                'https://en.wikipedia.org/wiki/Breed_type_(dog)'],
#               ['Rare breed (dog)',
#                'Indian National Kennel Club',
#                'Dog World (newspaper)',
#                'Kennel',
#                'Dog'],
#               ['https://en.wikipedia.org/wiki/Rare_breed_(dog)',
#                'https://en.wikipedia.org/wiki/Indian_National_Kennel_Club',
#                'https://en.wikipedia.org/wiki/Dog_World_(newspaper)',
#                'https://en.wikipedia.org/wiki/Kennel',
#                'https://en.wikipedia.org/wiki/Dog'],
#               [0.32988995313644409,
#                0.20292694866657257,
#                0.19846366345882416,
#                0.17250028252601624,
#                0.17051418125629425]],
#              'Cabbit': [['Cabbit', 'Cabbit', 'Cabbit', 'Cabbit', 'Cabbit'],
#               ['https://en.wikipedia.org/wiki/Cabbit',
#                'https://en.wikipedia.org/wiki/Cabbit',
#                'https://en.wikipedia.org/wiki/Cabbit',
#                'https://en.wikipedia.org/wiki/Cabbit',
#                'https://en.wikipedia.org/wiki/Cabbit'],
#               ['Cat',
#                'Cat anatomy',
#                'Canid hybrid',
#                'Ailurophobia',
#                'Cultural depictions of cats'],
#               ['https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Cat_anatomy',
#                'https://en.wikipedia.org/wiki/Canid_hybrid',
#                'https://en.wikipedia.org/wiki/Ailurophobia',
#                'https://en.wikipedia.org/wiki/Cultural_depictions_of_cats'],
#               [0.12192490696907043,
#                0.1068551242351532,
#                0.10148078203201294,
#                0.098001338541507721,
#                0.085882045328617096]],
#              'Canid hybrid': [['Canid hybrid',
#                'Canid hybrid',
#                'Canid hybrid',
#                'Canid hybrid',
#                'Canid hybrid'],
#               ['https://en.wikipedia.org/wiki/Canid_hybrid',
#                'https://en.wikipedia.org/wiki/Canid_hybrid',
#                'https://en.wikipedia.org/wiki/Canid_hybrid',
#                'https://en.wikipedia.org/wiki/Canid_hybrid',
#                'https://en.wikipedia.org/wiki/Canid_hybrid'],
#               ['Origin of the domestic dog',
#                'Dog',
#                'Interbreeding of dingoes with other domestic dogs',
#                'Pack (canine)',
#                'Cat'],
#               ['https://en.wikipedia.org/wiki/Origin_of_the_domestic_dog',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Interbreeding_of_dingoes_with_other_domestic_dogs',
#                'https://en.wikipedia.org/wiki/Pack_(canine)',
#                'https://en.wikipedia.org/wiki/Cat'],
#               [0.40113210678100586,
#                0.3622831404209137,
#                0.35488834977149963,
#                0.27051609754562378,
#                0.17282995581626892]],
#              'Canine Efficiency': [['Canine Efficiency',
#                'Canine Efficiency',
#                'Canine Efficiency',
#                'Canine Efficiency',
#                'Canine Efficiency'],
#               ['https://en.wikipedia.org/wiki/Canine_Efficiency',
#                'https://en.wikipedia.org/wiki/Canine_Efficiency',
#                'https://en.wikipedia.org/wiki/Canine_Efficiency',
#                'https://en.wikipedia.org/wiki/Canine_Efficiency',
#                'https://en.wikipedia.org/wiki/Canine_Efficiency'],
#               ['Dog',
#                'Dog bite prevention',
#                'Rabies in Haiti',
#                'Canine reproduction',
#                'Human–canine bond'],
#               ['https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Dog_bite_prevention',
#                'https://en.wikipedia.org/wiki/Rabies_in_Haiti',
#                'https://en.wikipedia.org/wiki/Canine_reproduction',
#                'https://en.wikipedia.org/wiki/Human–canine_bond'],
#               [0.047306112945079803,
#                0.045762341469526291,
#                0.044764608144760132,
#                0.042526319622993469,
#                0.041176337748765945]],
#              'Canine physical therapy': [['Canine physical therapy',
#                'Canine physical therapy',
#                'Canine physical therapy',
#                'Canine physical therapy',
#                'Canine physical therapy'],
#               ['https://en.wikipedia.org/wiki/Canine_physical_therapy',
#                'https://en.wikipedia.org/wiki/Canine_physical_therapy',
#                'https://en.wikipedia.org/wiki/Canine_physical_therapy',
#                'https://en.wikipedia.org/wiki/Canine_physical_therapy',
#                'https://en.wikipedia.org/wiki/Canine_physical_therapy'],
#               ['Therapy cat',
#                'Cynophobia',
#                'Human–canine bond',
#                'Cat anatomy',
#                'Dog'],
#               ['https://en.wikipedia.org/wiki/Therapy_cat',
#                'https://en.wikipedia.org/wiki/Cynophobia',
#                'https://en.wikipedia.org/wiki/Human–canine_bond',
#                'https://en.wikipedia.org/wiki/Cat_anatomy',
#                'https://en.wikipedia.org/wiki/Dog'],
#               [0.30368340015411377,
#                0.15485954284667969,
#                0.13063503801822662,
#                0.10080563277006149,
#                0.087686195969581604]],
#              'Canine reproduction': [['Canine reproduction',
#                'Canine reproduction',
#                'Canine reproduction',
#                'Canine reproduction',
#                'Canine reproduction'],
#               ['https://en.wikipedia.org/wiki/Canine_reproduction',
#                'https://en.wikipedia.org/wiki/Canine_reproduction',
#                'https://en.wikipedia.org/wiki/Canine_reproduction',
#                'https://en.wikipedia.org/wiki/Canine_reproduction',
#                'https://en.wikipedia.org/wiki/Canine_reproduction'],
#               ['Dog',
#                'Cat',
#                'Origin of the domestic dog',
#                'Human interaction with cats',
#                'Canid hybrid'],
#               ['https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Origin_of_the_domestic_dog',
#                'https://en.wikipedia.org/wiki/Human_interaction_with_cats',
#                'https://en.wikipedia.org/wiki/Canid_hybrid'],
#               [0.38652613759040833,
#                0.30040481686592102,
#                0.2226940244436264,
#                0.21100929379463196,
#                0.16468507051467896]],
#              'Cat': [['Cat', 'Cat', 'Cat', 'Cat', 'Cat'],
#               ['https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Cat'],
#               ['Feral cat',
#                'Human interaction with cats',
#                'Dog',
#                'Cat predation on wildlife',
#                'Cat senses'],
#               ['https://en.wikipedia.org/wiki/Feral_cat',
#                'https://en.wikipedia.org/wiki/Human_interaction_with_cats',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Cat_predation_on_wildlife',
#                'https://en.wikipedia.org/wiki/Cat_senses'],
#               [0.54995101690292358,
#                0.52186226844787598,
#                0.516274094581604,
#                0.41055434942245483,
#                0.39647135138511658]],
#              'Cat anatomy': [['Cat anatomy',
#                'Cat anatomy',
#                'Cat anatomy',
#                'Cat anatomy',
#                'Cat anatomy'],
#               ['https://en.wikipedia.org/wiki/Cat_anatomy',
#                'https://en.wikipedia.org/wiki/Cat_anatomy',
#                'https://en.wikipedia.org/wiki/Cat_anatomy',
#                'https://en.wikipedia.org/wiki/Cat_anatomy',
#                'https://en.wikipedia.org/wiki/Cat_anatomy'],
#               ['Cat',
#                'Human interaction with cats',
#                'Cultural depictions of cats',
#                'Cat senses',
#                'Cat meat'],
#               ['https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Human_interaction_with_cats',
#                'https://en.wikipedia.org/wiki/Cultural_depictions_of_cats',
#                'https://en.wikipedia.org/wiki/Cat_senses',
#                'https://en.wikipedia.org/wiki/Cat_meat'],
#               [0.32288014888763428,
#                0.20548465847969055,
#                0.19089514017105103,
#                0.18343758583068848,
#                0.16903139650821686]],
#              'Cat bite': [['Cat bite',
#                'Cat bite',
#                'Cat bite',
#                'Cat bite',
#                'Cat bite'],
#               ['https://en.wikipedia.org/wiki/Cat_bite',
#                'https://en.wikipedia.org/wiki/Cat_bite',
#                'https://en.wikipedia.org/wiki/Cat_bite',
#                'https://en.wikipedia.org/wiki/Cat_bite',
#                'https://en.wikipedia.org/wiki/Cat_bite'],
#               ['Dog bite',
#                'Feline zoonosis',
#                'Dog bite prevention',
#                'Cat',
#                'Rabies in Haiti'],
#               ['https://en.wikipedia.org/wiki/Dog_bite',
#                'https://en.wikipedia.org/wiki/Feline_zoonosis',
#                'https://en.wikipedia.org/wiki/Dog_bite_prevention',
#                'https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Rabies_in_Haiti'],
#               [0.48470771312713623,
#                0.47250688076019287,
#                0.42625930905342102,
#                0.29166477918624878,
#                0.26446059346199036]],
#              'Cat café': [['Cat café',
#                'Cat café',
#                'Cat café',
#                'Cat café',
#                'Cat café'],
#               ['https://en.wikipedia.org/wiki/Cat_café',
#                'https://en.wikipedia.org/wiki/Cat_café',
#                'https://en.wikipedia.org/wiki/Cat_café',
#                'https://en.wikipedia.org/wiki/Cat_café',
#                'https://en.wikipedia.org/wiki/Cat_café'],
#               ['Crumbs and Whiskers',
#                'Koneko (cat cafe)',
#                'Purringtons Cat Lounge',
#                'Cat',
#                'Cultural depictions of cats'],
#               ['https://en.wikipedia.org/wiki/Crumbs_and_Whiskers',
#                'https://en.wikipedia.org/wiki/Koneko_(cat_cafe)',
#                'https://en.wikipedia.org/wiki/Purringtons_Cat_Lounge',
#                'https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Cultural_depictions_of_cats'],
#               [0.63003689050674438,
#                0.57372176647186279,
#                0.32031410932540894,
#                0.16359986364841461,
#                0.14660303294658661]],
#              'Cat coat genetics': [['Cat coat genetics',
#                'Cat coat genetics',
#                'Cat coat genetics',
#                'Cat coat genetics',
#                'Cat coat genetics'],
#               ['https://en.wikipedia.org/wiki/Cat_coat_genetics',
#                'https://en.wikipedia.org/wiki/Cat_coat_genetics',
#                'https://en.wikipedia.org/wiki/Cat_coat_genetics',
#                'https://en.wikipedia.org/wiki/Cat_coat_genetics',
#                'https://en.wikipedia.org/wiki/Cat_coat_genetics'],
#               ['Point coloration',
#                'Deaf white cat',
#                'Roan (color)',
#                'Cat senses',
#                'Cat'],
#               ['https://en.wikipedia.org/wiki/Point_coloration',
#                'https://en.wikipedia.org/wiki/Deaf_white_cat',
#                'https://en.wikipedia.org/wiki/Roan_(color)',
#                'https://en.wikipedia.org/wiki/Cat_senses',
#                'https://en.wikipedia.org/wiki/Cat'],
#               [0.38747602701187134,
#                0.26394391059875488,
#                0.17459931969642639,
#                0.15959902107715607,
#                0.15044154226779938]],
#              'Cat gap': [['Cat gap',
#                'Cat gap',
#                'Cat gap',
#                'Cat gap',
#                'Cat gap'],
#               ['https://en.wikipedia.org/wiki/Cat_gap',
#                'https://en.wikipedia.org/wiki/Cat_gap',
#                'https://en.wikipedia.org/wiki/Cat_gap',
#                'https://en.wikipedia.org/wiki/Cat_gap',
#                'https://en.wikipedia.org/wiki/Cat_gap'],
#               ['Cat',
#                'Origin of the domestic dog',
#                'Dog',
#                'Human interaction with cats',
#                'Cat predation on wildlife'],
#               ['https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Origin_of_the_domestic_dog',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Human_interaction_with_cats',
#                'https://en.wikipedia.org/wiki/Cat_predation_on_wildlife'],
#               [0.24032343924045563,
#                0.16932559013366699,
#                0.16228824853897095,
#                0.15009514987468719,
#                0.12685871124267578]],
#              'Cat lady': [['Cat lady',
#                'Cat lady',
#                'Cat lady',
#                'Cat lady',
#                'Cat lady'],
#               ['https://en.wikipedia.org/wiki/Cat_lady',
#                'https://en.wikipedia.org/wiki/Cat_lady',
#                'https://en.wikipedia.org/wiki/Cat_lady',
#                'https://en.wikipedia.org/wiki/Cat_lady',
#                'https://en.wikipedia.org/wiki/Cat_lady'],
#               ['Human interaction with cats',
#                'Cat',
#                'Cultural depictions of cats',
#                'Cat meat',
#                'Cat café'],
#               ['https://en.wikipedia.org/wiki/Human_interaction_with_cats',
#                'https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Cultural_depictions_of_cats',
#                'https://en.wikipedia.org/wiki/Cat_meat',
#                'https://en.wikipedia.org/wiki/Cat_café'],
#               [0.20023249089717865,
#                0.14420224726200104,
#                0.12873613834381104,
#                0.10550467669963837,
#                0.10495205223560333]],
#              'Cat meat': [['Cat meat',
#                'Cat meat',
#                'Cat meat',
#                'Cat meat',
#                'Cat meat'],
#               ['https://en.wikipedia.org/wiki/Cat_meat',
#                'https://en.wikipedia.org/wiki/Cat_meat',
#                'https://en.wikipedia.org/wiki/Cat_meat',
#                'https://en.wikipedia.org/wiki/Cat_meat',
#                'https://en.wikipedia.org/wiki/Cat_meat'],
#               ['Dog meat',
#                'Lychee and Dog Meat Festival',
#                'Cat',
#                'Human interaction with cats',
#                'Cultural depictions of cats'],
#               ['https://en.wikipedia.org/wiki/Dog_meat',
#                'https://en.wikipedia.org/wiki/Lychee_and_Dog_Meat_Festival',
#                'https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Human_interaction_with_cats',
#                'https://en.wikipedia.org/wiki/Cultural_depictions_of_cats'],
#               [0.55845868587493896,
#                0.34467384219169617,
#                0.26219421625137329,
#                0.23746420443058014,
#                0.20398284494876862]],
#              'Cat predation on wildlife': [['Cat predation on wildlife',
#                'Cat predation on wildlife',
#                'Cat predation on wildlife',
#                'Cat predation on wildlife',
#                'Cat predation on wildlife'],
#               ['https://en.wikipedia.org/wiki/Cat_predation_on_wildlife',
#                'https://en.wikipedia.org/wiki/Cat_predation_on_wildlife',
#                'https://en.wikipedia.org/wiki/Cat_predation_on_wildlife',
#                'https://en.wikipedia.org/wiki/Cat_predation_on_wildlife',
#                'https://en.wikipedia.org/wiki/Cat_predation_on_wildlife'],
#               ['Feral cat',
#                'Cat',
#                'Dog',
#                'Human interaction with cats',
#                'Cultural depictions of cats'],
#               ['https://en.wikipedia.org/wiki/Feral_cat',
#                'https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Human_interaction_with_cats',
#                'https://en.wikipedia.org/wiki/Cultural_depictions_of_cats'],
#               [0.43459510803222656,
#                0.41055434942245483,
#                0.19528515636920929,
#                0.18951235711574554,
#                0.17708763480186462]],
#              'Cat senses': [['Cat senses',
#                'Cat senses',
#                'Cat senses',
#                'Cat senses',
#                'Cat senses'],
#               ['https://en.wikipedia.org/wiki/Cat_senses',
#                'https://en.wikipedia.org/wiki/Cat_senses',
#                'https://en.wikipedia.org/wiki/Cat_senses',
#                'https://en.wikipedia.org/wiki/Cat_senses',
#                'https://en.wikipedia.org/wiki/Cat_senses'],
#               ['Cat',
#                'Deaf white cat',
#                'Human interaction with cats',
#                'Dog',
#                'Feral cat'],
#               ['https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Deaf_white_cat',
#                'https://en.wikipedia.org/wiki/Human_interaction_with_cats',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Feral_cat'],
#               [0.39647135138511658,
#                0.26419523358345032,
#                0.25011196732521057,
#                0.24177716672420502,
#                0.19126443564891815]],
#              'Cat training': [['Cat training',
#                'Cat training',
#                'Cat training',
#                'Cat training',
#                'Cat training'],
#               ['https://en.wikipedia.org/wiki/Cat_training',
#                'https://en.wikipedia.org/wiki/Cat_training',
#                'https://en.wikipedia.org/wiki/Cat_training',
#                'https://en.wikipedia.org/wiki/Cat_training',
#                'https://en.wikipedia.org/wiki/Cat_training'],
#               ['Human interaction with cats',
#                'Cat',
#                'Cultural depictions of cats',
#                'Cat anatomy',
#                'Cynology'],
#               ['https://en.wikipedia.org/wiki/Human_interaction_with_cats',
#                'https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Cultural_depictions_of_cats',
#                'https://en.wikipedia.org/wiki/Cat_anatomy',
#                'https://en.wikipedia.org/wiki/Cynology'],
#               [0.24833448231220245,
#                0.19893567264080048,
#                0.14018461108207703,
#                0.12914654612541199,
#                0.12467522919178009]],
#              'Cat-burning': [['Cat-burning',
#                'Cat-burning',
#                'Cat-burning',
#                'Cat-burning',
#                'Cat-burning'],
#               ['https://en.wikipedia.org/wiki/Cat-burning',
#                'https://en.wikipedia.org/wiki/Cat-burning',
#                'https://en.wikipedia.org/wiki/Cat-burning',
#                'https://en.wikipedia.org/wiki/Cat-burning',
#                'https://en.wikipedia.org/wiki/Cat-burning'],
#               ['Cat',
#                'Cultural depictions of cats',
#                'Cat meat',
#                'Human interaction with cats',
#                'Saint Guinefort'],
#               ['https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Cultural_depictions_of_cats',
#                'https://en.wikipedia.org/wiki/Cat_meat',
#                'https://en.wikipedia.org/wiki/Human_interaction_with_cats',
#                'https://en.wikipedia.org/wiki/Saint_Guinefort'],
#               [0.16775745153427124,
#                0.13982541859149933,
#                0.11302316933870316,
#                0.091186411678791046,
#                0.086511008441448212]],
#              'Cats in ancient Egypt': [['Cats in ancient Egypt',
#                'Cats in ancient Egypt',
#                'Cats in ancient Egypt',
#                'Cats in ancient Egypt',
#                'Cats in ancient Egypt'],
#               ['https://en.wikipedia.org/wiki/Cats_in_ancient_Egypt',
#                'https://en.wikipedia.org/wiki/Cats_in_ancient_Egypt',
#                'https://en.wikipedia.org/wiki/Cats_in_ancient_Egypt',
#                'https://en.wikipedia.org/wiki/Cats_in_ancient_Egypt',
#                'https://en.wikipedia.org/wiki/Cats_in_ancient_Egypt'],
#               ['Cultural depictions of cats',
#                'Cat',
#                'Dogs in religion',
#                'Human interaction with cats',
#                'Dogs in ancient China'],
#               ['https://en.wikipedia.org/wiki/Cultural_depictions_of_cats',
#                'https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Dogs_in_religion',
#                'https://en.wikipedia.org/wiki/Human_interaction_with_cats',
#                'https://en.wikipedia.org/wiki/Dogs_in_ancient_China'],
#               [0.22308902442455292,
#                0.21550315618515015,
#                0.18769536912441254,
#                0.13890022039413452,
#                0.12342812865972519]],
#              'Cattery': [['Cattery',
#                'Cattery',
#                'Cattery',
#                'Cattery',
#                'Cattery'],
#               ['https://en.wikipedia.org/wiki/Cattery',
#                'https://en.wikipedia.org/wiki/Cattery',
#                'https://en.wikipedia.org/wiki/Cattery',
#                'https://en.wikipedia.org/wiki/Cattery',
#                'https://en.wikipedia.org/wiki/Cattery'],
#               ['Kennel',
#                'Cat',
#                'Cultural depictions of cats',
#                'Human interaction with cats',
#                'Dog daycare'],
#               ['https://en.wikipedia.org/wiki/Kennel',
#                'https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Cultural_depictions_of_cats',
#                'https://en.wikipedia.org/wiki/Human_interaction_with_cats',
#                'https://en.wikipedia.org/wiki/Dog_daycare'],
#               [0.33596238493919373,
#                0.082259714603424072,
#                0.074950084090232849,
#                0.07277090847492218,
#                0.065502472221851349]],
#              'Chiengora': [['Chiengora',
#                'Chiengora',
#                'Chiengora',
#                'Chiengora',
#                'Chiengora'],
#               ['https://en.wikipedia.org/wiki/Chiengora',
#                'https://en.wikipedia.org/wiki/Chiengora',
#                'https://en.wikipedia.org/wiki/Chiengora',
#                'https://en.wikipedia.org/wiki/Chiengora',
#                'https://en.wikipedia.org/wiki/Chiengora'],
#               ['Dog',
#                'Cultural depictions of cats',
#                'Cat meat',
#                'Pussy',
#                'Dog food'],
#               ['https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Cultural_depictions_of_cats',
#                'https://en.wikipedia.org/wiki/Cat_meat',
#                'https://en.wikipedia.org/wiki/Pussy',
#                'https://en.wikipedia.org/wiki/Dog_food'],
#               [0.078324943780899048,
#                0.064400382339954376,
#                0.055054977536201477,
#                0.05468754842877388,
#                0.053463466465473175]],
#              'Cropping (animal)': [['Cropping (animal)',
#                'Cropping (animal)',
#                'Cropping (animal)',
#                'Cropping (animal)',
#                'Cropping (animal)'],
#               ['https://en.wikipedia.org/wiki/Cropping_(animal)',
#                'https://en.wikipedia.org/wiki/Cropping_(animal)',
#                'https://en.wikipedia.org/wiki/Cropping_(animal)',
#                'https://en.wikipedia.org/wiki/Cropping_(animal)',
#                'https://en.wikipedia.org/wiki/Cropping_(animal)'],
#               ['Puppy',
#                'Dog',
#                'Cat',
#                'Human interaction with cats',
#                'Body language of dogs'],
#               ['https://en.wikipedia.org/wiki/Puppy',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Human_interaction_with_cats',
#                'https://en.wikipedia.org/wiki/Body_language_of_dogs'],
#               [0.26505273580551147,
#                0.11020703613758087,
#                0.093295946717262268,
#                0.079773828387260437,
#                0.078724279999732971]],
#              'Crumbs and Whiskers': [['Crumbs and Whiskers',
#                'Crumbs and Whiskers',
#                'Crumbs and Whiskers',
#                'Crumbs and Whiskers',
#                'Crumbs and Whiskers'],
#               ['https://en.wikipedia.org/wiki/Crumbs_and_Whiskers',
#                'https://en.wikipedia.org/wiki/Crumbs_and_Whiskers',
#                'https://en.wikipedia.org/wiki/Crumbs_and_Whiskers',
#                'https://en.wikipedia.org/wiki/Crumbs_and_Whiskers',
#                'https://en.wikipedia.org/wiki/Crumbs_and_Whiskers'],
#               ['Cat café',
#                'Koneko (cat cafe)',
#                'Purringtons Cat Lounge',
#                'Cat senses',
#                'Dogs in the American Revolutionary War'],
#               ['https://en.wikipedia.org/wiki/Cat_café',
#                'https://en.wikipedia.org/wiki/Koneko_(cat_cafe)',
#                'https://en.wikipedia.org/wiki/Purringtons_Cat_Lounge',
#                'https://en.wikipedia.org/wiki/Cat_senses',
#                'https://en.wikipedia.org/wiki/Dogs_in_the_American_Revolutionary_War'],
#               [0.63003689050674438,
#                0.36866900324821472,
#                0.18602162599563599,
#                0.13124194741249084,
#                0.11093950271606445]],
#              'Cultural depictions of cats': [['Cultural depictions of cats',
#                'Cultural depictions of cats',
#                'Cultural depictions of cats',
#                'Cultural depictions of cats',
#                'Cultural depictions of cats'],
#               ['https://en.wikipedia.org/wiki/Cultural_depictions_of_cats',
#                'https://en.wikipedia.org/wiki/Cultural_depictions_of_cats',
#                'https://en.wikipedia.org/wiki/Cultural_depictions_of_cats',
#                'https://en.wikipedia.org/wiki/Cultural_depictions_of_cats',
#                'https://en.wikipedia.org/wiki/Cultural_depictions_of_cats'],
#               ['Cat',
#                'Human interaction with cats',
#                'Cats in ancient Egypt',
#                'Cat meat',
#                'Cat anatomy'],
#               ['https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Human_interaction_with_cats',
#                'https://en.wikipedia.org/wiki/Cats_in_ancient_Egypt',
#                'https://en.wikipedia.org/wiki/Cat_meat',
#                'https://en.wikipedia.org/wiki/Cat_anatomy'],
#               [0.32451063394546509,
#                0.22382217645645142,
#                0.22308902442455292,
#                0.20398284494876862,
#                0.19089514017105103]],
#              'Cynology': [['Cynology',
#                'Cynology',
#                'Cynology',
#                'Cynology',
#                'Cynology'],
#               ['https://en.wikipedia.org/wiki/Cynology',
#                'https://en.wikipedia.org/wiki/Cynology',
#                'https://en.wikipedia.org/wiki/Cynology',
#                'https://en.wikipedia.org/wiki/Cynology',
#                'https://en.wikipedia.org/wiki/Cynology'],
#               ['Dog',
#                'Breed type (dog)',
#                'Cat training',
#                'Pussy',
#                'Felinology'],
#               ['https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Breed_type_(dog)',
#                'https://en.wikipedia.org/wiki/Cat_training',
#                'https://en.wikipedia.org/wiki/Pussy',
#                'https://en.wikipedia.org/wiki/Felinology'],
#               [0.14337702095508575,
#                0.12778478860855103,
#                0.12467522919178009,
#                0.11715327948331833,
#                0.10835662484169006]],
#              'Cynophobia': [['Cynophobia',
#                'Cynophobia',
#                'Cynophobia',
#                'Cynophobia',
#                'Cynophobia'],
#               ['https://en.wikipedia.org/wiki/Cynophobia',
#                'https://en.wikipedia.org/wiki/Cynophobia',
#                'https://en.wikipedia.org/wiki/Cynophobia',
#                'https://en.wikipedia.org/wiki/Cynophobia',
#                'https://en.wikipedia.org/wiki/Cynophobia'],
#               ['Ailurophobia',
#                'Therapy cat',
#                'Dog',
#                'Canine physical therapy',
#                'Cat'],
#               ['https://en.wikipedia.org/wiki/Ailurophobia',
#                'https://en.wikipedia.org/wiki/Therapy_cat',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Canine_physical_therapy',
#                'https://en.wikipedia.org/wiki/Cat'],
#               [0.30192595720291138,
#                0.29925444722175598,
#                0.17738708853721619,
#                0.15485954284667969,
#                0.14030085504055023]],
#              'Deaf white cat': [['Deaf white cat',
#                'Deaf white cat',
#                'Deaf white cat',
#                'Deaf white cat',
#                'Deaf white cat'],
#               ['https://en.wikipedia.org/wiki/Deaf_white_cat',
#                'https://en.wikipedia.org/wiki/Deaf_white_cat',
#                'https://en.wikipedia.org/wiki/Deaf_white_cat',
#                'https://en.wikipedia.org/wiki/Deaf_white_cat',
#                'https://en.wikipedia.org/wiki/Deaf_white_cat'],
#               ['Cat senses',
#                'Cat coat genetics',
#                'Point coloration',
#                'Roan (color)',
#                'Cat'],
#               ['https://en.wikipedia.org/wiki/Cat_senses',
#                'https://en.wikipedia.org/wiki/Cat_coat_genetics',
#                'https://en.wikipedia.org/wiki/Point_coloration',
#                'https://en.wikipedia.org/wiki/Roan_(color)',
#                'https://en.wikipedia.org/wiki/Cat'],
#               [0.26419523358345032,
#                0.26394391059875488,
#                0.18055142462253571,
#                0.13945192098617554,
#                0.11110901087522507]],
#              'Dog': [['Dog', 'Dog', 'Dog', 'Dog', 'Dog'],
#               ['https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Dog'],
#               ['Origin of the domestic dog',
#                'Cat',
#                'Canine reproduction',
#                'Canid hybrid',
#                'Human interaction with cats'],
#               ['https://en.wikipedia.org/wiki/Origin_of_the_domestic_dog',
#                'https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Canine_reproduction',
#                'https://en.wikipedia.org/wiki/Canid_hybrid',
#                'https://en.wikipedia.org/wiki/Human_interaction_with_cats'],
#               [0.58130085468292236,
#                0.516274094581604,
#                0.38652613759040833,
#                0.3622831404209137,
#                0.35789269208908081]],
#              'Dog Parker': [['Dog Parker',
#                'Dog Parker',
#                'Dog Parker',
#                'Dog Parker',
#                'Dog Parker'],
#               ['https://en.wikipedia.org/wiki/Dog_Parker',
#                'https://en.wikipedia.org/wiki/Dog_Parker',
#                'https://en.wikipedia.org/wiki/Dog_Parker',
#                'https://en.wikipedia.org/wiki/Dog_Parker',
#                'https://en.wikipedia.org/wiki/Dog_Parker'],
#               ['Dog',
#                'Service dog',
#                'Dogs in the American Revolutionary War',
#                'Dog meat',
#                'Dog daycare'],
#               ['https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Service_dog',
#                'https://en.wikipedia.org/wiki/Dogs_in_the_American_Revolutionary_War',
#                'https://en.wikipedia.org/wiki/Dog_meat',
#                'https://en.wikipedia.org/wiki/Dog_daycare'],
#               [0.087380088865756989,
#                0.064433753490447998,
#                0.060531586408615112,
#                0.056024476885795593,
#                0.054267846047878265]],
#              'Dog World (newspaper)': [['Dog World (newspaper)',
#                'Dog World (newspaper)',
#                'Dog World (newspaper)',
#                'Dog World (newspaper)',
#                'Dog World (newspaper)'],
#               ['https://en.wikipedia.org/wiki/Dog_World_(newspaper)',
#                'https://en.wikipedia.org/wiki/Dog_World_(newspaper)',
#                'https://en.wikipedia.org/wiki/Dog_World_(newspaper)',
#                'https://en.wikipedia.org/wiki/Dog_World_(newspaper)',
#                'https://en.wikipedia.org/wiki/Dog_World_(newspaper)'],
#               ['Indian National Kennel Club',
#                'Breed type (dog)',
#                'Dog',
#                'Lists of dogs',
#                'Kennel'],
#               ['https://en.wikipedia.org/wiki/Indian_National_Kennel_Club',
#                'https://en.wikipedia.org/wiki/Breed_type_(dog)',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Lists_of_dogs',
#                'https://en.wikipedia.org/wiki/Kennel'],
#               [0.22606229782104492,
#                0.19846366345882416,
#                0.16916643083095551,
#                0.14456522464752197,
#                0.13536316156387329]],
#              'Dog biscuit': [['Dog biscuit',
#                'Dog biscuit',
#                'Dog biscuit',
#                'Dog biscuit',
#                'Dog biscuit'],
#               ['https://en.wikipedia.org/wiki/Dog_biscuit',
#                'https://en.wikipedia.org/wiki/Dog_biscuit',
#                'https://en.wikipedia.org/wiki/Dog_biscuit',
#                'https://en.wikipedia.org/wiki/Dog_biscuit',
#                'https://en.wikipedia.org/wiki/Dog_biscuit'],
#               ['Dog food', 'Dog meat', 'Dog daycare', 'Cat meat', 'Dog'],
#               ['https://en.wikipedia.org/wiki/Dog_food',
#                'https://en.wikipedia.org/wiki/Dog_meat',
#                'https://en.wikipedia.org/wiki/Dog_daycare',
#                'https://en.wikipedia.org/wiki/Cat_meat',
#                'https://en.wikipedia.org/wiki/Dog'],
#               [0.25327244400978088,
#                0.15528811514377594,
#                0.12897235155105591,
#                0.12838608026504517,
#                0.097315944731235504]],
#              'Dog bite': [['Dog bite',
#                'Dog bite',
#                'Dog bite',
#                'Dog bite',
#                'Dog bite'],
#               ['https://en.wikipedia.org/wiki/Dog_bite',
#                'https://en.wikipedia.org/wiki/Dog_bite',
#                'https://en.wikipedia.org/wiki/Dog_bite',
#                'https://en.wikipedia.org/wiki/Dog_bite',
#                'https://en.wikipedia.org/wiki/Dog_bite'],
#               ['Dog bite prevention',
#                'Cat bite',
#                'Dog',
#                'Feline zoonosis',
#                'Rabies in Haiti'],
#               ['https://en.wikipedia.org/wiki/Dog_bite_prevention',
#                'https://en.wikipedia.org/wiki/Cat_bite',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Feline_zoonosis',
#                'https://en.wikipedia.org/wiki/Rabies_in_Haiti'],
#               [0.53842276334762573,
#                0.48470771312713623,
#                0.27171269059181213,
#                0.22283630073070526,
#                0.18469922244548798]],
#              'Dog bite prevention': [['Dog bite prevention',
#                'Dog bite prevention',
#                'Dog bite prevention',
#                'Dog bite prevention',
#                'Dog bite prevention'],
#               ['https://en.wikipedia.org/wiki/Dog_bite_prevention',
#                'https://en.wikipedia.org/wiki/Dog_bite_prevention',
#                'https://en.wikipedia.org/wiki/Dog_bite_prevention',
#                'https://en.wikipedia.org/wiki/Dog_bite_prevention',
#                'https://en.wikipedia.org/wiki/Dog_bite_prevention'],
#               ['Dog bite',
#                'Cat bite',
#                'Body language of dogs',
#                'Feline zoonosis',
#                'Tail wagging by dogs'],
#               ['https://en.wikipedia.org/wiki/Dog_bite',
#                'https://en.wikipedia.org/wiki/Cat_bite',
#                'https://en.wikipedia.org/wiki/Body_language_of_dogs',
#                'https://en.wikipedia.org/wiki/Feline_zoonosis',
#                'https://en.wikipedia.org/wiki/Tail_wagging_by_dogs'],
#               [0.53842276334762573,
#                0.42625930905342102,
#                0.37101003527641296,
#                0.26550114154815674,
#                0.25909522175788879]],
#              'Dog daycare': [['Dog daycare',
#                'Dog daycare',
#                'Dog daycare',
#                'Dog daycare',
#                'Dog daycare'],
#               ['https://en.wikipedia.org/wiki/Dog_daycare',
#                'https://en.wikipedia.org/wiki/Dog_daycare',
#                'https://en.wikipedia.org/wiki/Dog_daycare',
#                'https://en.wikipedia.org/wiki/Dog_daycare',
#                'https://en.wikipedia.org/wiki/Dog_daycare'],
#               ['International Cat Day',
#                'Dog',
#                'Dog meat',
#                'Dog biscuit',
#                'Dog World (newspaper)'],
#               ['https://en.wikipedia.org/wiki/International_Cat_Day',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Dog_meat',
#                'https://en.wikipedia.org/wiki/Dog_biscuit',
#                'https://en.wikipedia.org/wiki/Dog_World_(newspaper)'],
#               [0.17273202538490295,
#                0.14947745203971863,
#                0.12920929491519928,
#                0.12897235155105591,
#                0.12254226207733154]],
#              'Dog food': [['Dog food',
#                'Dog food',
#                'Dog food',
#                'Dog food',
#                'Dog food'],
#               ['https://en.wikipedia.org/wiki/Dog_food',
#                'https://en.wikipedia.org/wiki/Dog_food',
#                'https://en.wikipedia.org/wiki/Dog_food',
#                'https://en.wikipedia.org/wiki/Dog_food',
#                'https://en.wikipedia.org/wiki/Dog_food'],
#               ['Dog biscuit', 'Dog meat', 'Dog', 'Cat', 'Cat meat'],
#               ['https://en.wikipedia.org/wiki/Dog_biscuit',
#                'https://en.wikipedia.org/wiki/Dog_meat',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Cat_meat'],
#               [0.25327244400978088,
#                0.24268804490566254,
#                0.22961516678333282,
#                0.21735206246376038,
#                0.19613023102283478]],
#              'Dog meat': [['Dog meat',
#                'Dog meat',
#                'Dog meat',
#                'Dog meat',
#                'Dog meat'],
#               ['https://en.wikipedia.org/wiki/Dog_meat',
#                'https://en.wikipedia.org/wiki/Dog_meat',
#                'https://en.wikipedia.org/wiki/Dog_meat',
#                'https://en.wikipedia.org/wiki/Dog_meat',
#                'https://en.wikipedia.org/wiki/Dog_meat'],
#               ['Cat meat',
#                'Lychee and Dog Meat Festival',
#                'Dog',
#                'Dog food',
#                'Dogs in ancient China'],
#               ['https://en.wikipedia.org/wiki/Cat_meat',
#                'https://en.wikipedia.org/wiki/Lychee_and_Dog_Meat_Festival',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Dog_food',
#                'https://en.wikipedia.org/wiki/Dogs_in_ancient_China'],
#               [0.55845868587493896,
#                0.5252341628074646,
#                0.26244699954986572,
#                0.24268804490566254,
#                0.18568655848503113]],
#              'Dogs in Mesoamerica': [['Dogs in Mesoamerica',
#                'Dogs in Mesoamerica',
#                'Dogs in Mesoamerica',
#                'Dogs in Mesoamerica',
#                'Dogs in Mesoamerica'],
#               ['https://en.wikipedia.org/wiki/Dogs_in_Mesoamerica',
#                'https://en.wikipedia.org/wiki/Dogs_in_Mesoamerica',
#                'https://en.wikipedia.org/wiki/Dogs_in_Mesoamerica',
#                'https://en.wikipedia.org/wiki/Dogs_in_Mesoamerica',
#                'https://en.wikipedia.org/wiki/Dogs_in_Mesoamerica'],
#               ['Dogs in ancient China',
#                'Dog',
#                'Dogs in religion',
#                'Dog meat',
#                'Origin of the domestic dog'],
#               ['https://en.wikipedia.org/wiki/Dogs_in_ancient_China',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Dogs_in_religion',
#                'https://en.wikipedia.org/wiki/Dog_meat',
#                'https://en.wikipedia.org/wiki/Origin_of_the_domestic_dog'],
#               [0.20320130884647369,
#                0.17091257870197296,
#                0.1659163236618042,
#                0.15780878067016602,
#                0.13782773911952972]],
#              'Dogs in ancient China': [['Dogs in ancient China',
#                'Dogs in ancient China',
# ...
#                'https://en.wikipedia.org/wiki/Pussy'],
#               ['Cat',
#                'Dog',
#                'Canine reproduction',
#                'Cynology',
#                'Cultural depictions of cats'],
#               ['https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Canine_reproduction',
#                'https://en.wikipedia.org/wiki/Cynology',
#                'https://en.wikipedia.org/wiki/Cultural_depictions_of_cats'],
#               [0.19860656559467316,
#                0.16119867563247681,
#                0.13556471467018127,
#                0.11715327948331833,
#                0.10642509907484055]],
#              "Queen Elizabeth's corgis": [["Queen Elizabeth's corgis",
#                "Queen Elizabeth's corgis",
#                "Queen Elizabeth's corgis",
#                "Queen Elizabeth's corgis",
#                "Queen Elizabeth's corgis"],
#               ["https://en.wikipedia.org/wiki/Queen_Elizabeth's_corgis",
#                "https://en.wikipedia.org/wiki/Queen_Elizabeth's_corgis",
#                "https://en.wikipedia.org/wiki/Queen_Elizabeth's_corgis",
#                "https://en.wikipedia.org/wiki/Queen_Elizabeth's_corgis",
#                "https://en.wikipedia.org/wiki/Queen_Elizabeth's_corgis"],
#               ['Dog daycare',
#                'Dog World (newspaper)',
#                'Dog',
#                'Cat meat',
#                'Cat'],
#               ['https://en.wikipedia.org/wiki/Dog_daycare',
#                'https://en.wikipedia.org/wiki/Dog_World_(newspaper)',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Cat_meat',
#                'https://en.wikipedia.org/wiki/Cat'],
#               [0.08517514169216156,
#                0.073924742639064789,
#                0.06987425684928894,
#                0.066491357982158661,
#                0.064443916082382202]],
#              'Rabies in Haiti': [['Rabies in Haiti',
#                'Rabies in Haiti',
#                'Rabies in Haiti',
#                'Rabies in Haiti',
#                'Rabies in Haiti'],
#               ['https://en.wikipedia.org/wiki/Rabies_in_Haiti',
#                'https://en.wikipedia.org/wiki/Rabies_in_Haiti',
#                'https://en.wikipedia.org/wiki/Rabies_in_Haiti',
#                'https://en.wikipedia.org/wiki/Rabies_in_Haiti',
#                'https://en.wikipedia.org/wiki/Rabies_in_Haiti'],
#               ['Cat bite',
#                'Dog bite prevention',
#                'Dog bite',
#                'Feline zoonosis',
#                'Dog'],
#               ['https://en.wikipedia.org/wiki/Cat_bite',
#                'https://en.wikipedia.org/wiki/Dog_bite_prevention',
#                'https://en.wikipedia.org/wiki/Dog_bite',
#                'https://en.wikipedia.org/wiki/Feline_zoonosis',
#                'https://en.wikipedia.org/wiki/Dog'],
#               [0.26446059346199036,
#                0.25128981471061707,
#                0.18469922244548798,
#                0.15853261947631836,
#                0.14090380072593689]],
#              'Rare breed (dog)': [['Rare breed (dog)',
#                'Rare breed (dog)',
#                'Rare breed (dog)',
#                'Rare breed (dog)',
#                'Rare breed (dog)'],
#               ['https://en.wikipedia.org/wiki/Rare_breed_(dog)',
#                'https://en.wikipedia.org/wiki/Rare_breed_(dog)',
#                'https://en.wikipedia.org/wiki/Rare_breed_(dog)',
#                'https://en.wikipedia.org/wiki/Rare_breed_(dog)',
#                'https://en.wikipedia.org/wiki/Rare_breed_(dog)'],
#               ['Breed type (dog)',
#                'Lists of dogs',
#                'Dog',
#                'Dog bite',
#                'Origin of the domestic dog'],
#               ['https://en.wikipedia.org/wiki/Breed_type_(dog)',
#                'https://en.wikipedia.org/wiki/Lists_of_dogs',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Dog_bite',
#                'https://en.wikipedia.org/wiki/Origin_of_the_domestic_dog'],
#               [0.32988995313644409,
#                0.16661007702350616,
#                0.16474558413028717,
#                0.13301719725131989,
#                0.117845818400383]],
#              'Roan (color)': [['Roan (color)',
#                'Roan (color)',
#                'Roan (color)',
#                'Roan (color)',
#                'Roan (color)'],
#               ['https://en.wikipedia.org/wiki/Roan_(color)',
#                'https://en.wikipedia.org/wiki/Roan_(color)',
#                'https://en.wikipedia.org/wiki/Roan_(color)',
#                'https://en.wikipedia.org/wiki/Roan_(color)',
#                'https://en.wikipedia.org/wiki/Roan_(color)'],
#               ['Cat coat genetics',
#                'Point coloration',
#                'Deaf white cat',
#                'Dog',
#                'Cat'],
#               ['https://en.wikipedia.org/wiki/Cat_coat_genetics',
#                'https://en.wikipedia.org/wiki/Point_coloration',
#                'https://en.wikipedia.org/wiki/Deaf_white_cat',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Cat'],
#               [0.17459931969642639,
#                0.1712733656167984,
#                0.13945192098617554,
#                0.078832216560840607,
#                0.074334271252155304]],
#              'Rolfi': [['Rolfi', 'Rolfi', 'Rolfi', 'Rolfi', 'Rolfi'],
#               ['https://en.wikipedia.org/wiki/Rolfi',
#                'https://en.wikipedia.org/wiki/Rolfi',
#                'https://en.wikipedia.org/wiki/Rolfi',
#                'https://en.wikipedia.org/wiki/Rolfi',
#                'https://en.wikipedia.org/wiki/Rolfi'],
#               ['Bog Dog',
#                'Cat anatomy',
#                'Dog',
#                'Dog bite',
#                'Point coloration'],
#               ['https://en.wikipedia.org/wiki/Bog_Dog',
#                'https://en.wikipedia.org/wiki/Cat_anatomy',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Dog_bite',
#                'https://en.wikipedia.org/wiki/Point_coloration'],
#               [0.40277498960494995,
#                0.020354922860860825,
#                0.019285188987851143,
#                0.019074155017733574,
#                0.018065502867102623]],
#              'Saint Guinefort': [['Saint Guinefort',
#                'Saint Guinefort',
#                'Saint Guinefort',
#                'Saint Guinefort',
#                'Saint Guinefort'],
#               ['https://en.wikipedia.org/wiki/Saint_Guinefort',
#                'https://en.wikipedia.org/wiki/Saint_Guinefort',
#                'https://en.wikipedia.org/wiki/Saint_Guinefort',
#                'https://en.wikipedia.org/wiki/Saint_Guinefort',
#                'https://en.wikipedia.org/wiki/Saint_Guinefort'],
#               ['Dogs in religion',
#                'Cat-burning',
#                'Dog',
#                'Cultural depictions of cats',
#                'Cat'],
#               ['https://en.wikipedia.org/wiki/Dogs_in_religion',
#                'https://en.wikipedia.org/wiki/Cat-burning',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Cultural_depictions_of_cats',
#                'https://en.wikipedia.org/wiki/Cat'],
#               [0.13819706439971924,
#                0.086511008441448212,
#                0.06382424384355545,
#                0.060487143695354462,
#                0.049028016626834869]],
#              'Service dog': [['Service dog',
#                'Service dog',
#                'Service dog',
#                'Service dog',
#                'Service dog'],
#               ['https://en.wikipedia.org/wiki/Service_dog',
#                'https://en.wikipedia.org/wiki/Service_dog',
#                'https://en.wikipedia.org/wiki/Service_dog',
#                'https://en.wikipedia.org/wiki/Service_dog',
#                'https://en.wikipedia.org/wiki/Service_dog'],
#               ['Therapy cat',
#                'Dog',
#                'Dog daycare',
#                'Human–canine bond',
#                'Dog bite'],
#               ['https://en.wikipedia.org/wiki/Therapy_cat',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Dog_daycare',
#                'https://en.wikipedia.org/wiki/Human–canine_bond',
#                'https://en.wikipedia.org/wiki/Dog_bite'],
#               [0.1528037041425705,
#                0.14040695130825043,
#                0.11555059254169464,
#                0.1044677346944809,
#                0.094058886170387268]],
#              'Tail wagging by dogs': [['Tail wagging by dogs',
#                'Tail wagging by dogs',
#                'Tail wagging by dogs',
#                'Tail wagging by dogs',
#                'Tail wagging by dogs'],
#               ['https://en.wikipedia.org/wiki/Tail_wagging_by_dogs',
#                'https://en.wikipedia.org/wiki/Tail_wagging_by_dogs',
#                'https://en.wikipedia.org/wiki/Tail_wagging_by_dogs',
#                'https://en.wikipedia.org/wiki/Tail_wagging_by_dogs',
#                'https://en.wikipedia.org/wiki/Tail_wagging_by_dogs'],
#               ['Body language of dogs',
#                'Dog bite prevention',
#                'Dog',
#                'Dog bite',
#                'Cropping (animal)'],
#               ['https://en.wikipedia.org/wiki/Body_language_of_dogs',
#                'https://en.wikipedia.org/wiki/Dog_bite_prevention',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Dog_bite',
#                'https://en.wikipedia.org/wiki/Cropping_(animal)'],
#               [0.60040205717086792,
#                0.25909522175788879,
#                0.092092595994472504,
#                0.090576350688934326,
#                0.063500978052616119]],
#              'The Dog Pillow': [['The Dog Pillow',
#                'The Dog Pillow',
#                'The Dog Pillow',
#                'The Dog Pillow',
#                'The Dog Pillow'],
#               ['https://en.wikipedia.org/wiki/The_Dog_Pillow',
#                'https://en.wikipedia.org/wiki/The_Dog_Pillow',
#                'https://en.wikipedia.org/wiki/The_Dog_Pillow',
#                'https://en.wikipedia.org/wiki/The_Dog_Pillow',
#                'https://en.wikipedia.org/wiki/The_Dog_Pillow'],
#               ['The Ten Commandments of Dog Ownership',
#                'Dog',
#                'Cat',
#                'Origin of the domestic dog',
#                'Human interaction with cats'],
#               ['https://en.wikipedia.org/wiki/The_Ten_Commandments_of_Dog_Ownership',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Origin_of_the_domestic_dog',
#                'https://en.wikipedia.org/wiki/Human_interaction_with_cats'],
#               [0.15579798817634583,
#                0.12909851968288422,
#                0.12729714810848236,
#                0.099896810948848724,
#                0.088844574987888336]],
#              'The Ten Commandments of Dog Ownership': [['The Ten Commandments of Dog Ownership',
#                'The Ten Commandments of Dog Ownership',
#                'The Ten Commandments of Dog Ownership',
#                'The Ten Commandments of Dog Ownership',
#                'The Ten Commandments of Dog Ownership'],
#               ['https://en.wikipedia.org/wiki/The_Ten_Commandments_of_Dog_Ownership',
#                'https://en.wikipedia.org/wiki/The_Ten_Commandments_of_Dog_Ownership',
#                'https://en.wikipedia.org/wiki/The_Ten_Commandments_of_Dog_Ownership',
#                'https://en.wikipedia.org/wiki/The_Ten_Commandments_of_Dog_Ownership',
#                'https://en.wikipedia.org/wiki/The_Ten_Commandments_of_Dog_Ownership'],
#               ['Walter the Farting Dog',
#                'The Dog Pillow',
#                'Dog',
#                'Dog World (newspaper)',
#                'Human interaction with cats'],
#               ['https://en.wikipedia.org/wiki/Walter_the_Farting_Dog',
#                'https://en.wikipedia.org/wiki/The_Dog_Pillow',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Dog_World_(newspaper)',
#                'https://en.wikipedia.org/wiki/Human_interaction_with_cats'],
#               [0.16809237003326416,
#                0.15579798817634583,
#                0.081471368670463562,
#                0.067874282598495483,
#                0.064066246151924133]],
#              'Therapy cat': [['Therapy cat',
#                'Therapy cat',
#                'Therapy cat',
#                'Therapy cat',
#                'Therapy cat'],
#               ['https://en.wikipedia.org/wiki/Therapy_cat',
#                'https://en.wikipedia.org/wiki/Therapy_cat',
#                'https://en.wikipedia.org/wiki/Therapy_cat',
#                'https://en.wikipedia.org/wiki/Therapy_cat',
#                'https://en.wikipedia.org/wiki/Therapy_cat'],
#               ['Canine physical therapy',
#                'Cynophobia',
#                'Human–canine bond',
#                'Service dog',
#                'Cat'],
#               ['https://en.wikipedia.org/wiki/Canine_physical_therapy',
#                'https://en.wikipedia.org/wiki/Cynophobia',
#                'https://en.wikipedia.org/wiki/Human–canine_bond',
#                'https://en.wikipedia.org/wiki/Service_dog',
#                'https://en.wikipedia.org/wiki/Cat'],
#               [0.30368340015411377,
#                0.29925444722175598,
#                0.19631733000278473,
#                0.1528037041425705,
#                0.13454185426235199]],
#              'Toe tuft': [['Toe tuft',
#                'Toe tuft',
#                'Toe tuft',
#                'Toe tuft',
#                'Toe tuft'],
#               ['https://en.wikipedia.org/wiki/Toe_tuft',
#                'https://en.wikipedia.org/wiki/Toe_tuft',
#                'https://en.wikipedia.org/wiki/Toe_tuft',
#                'https://en.wikipedia.org/wiki/Toe_tuft',
#                'https://en.wikipedia.org/wiki/Toe_tuft'],
#               ['Cat',
#                'Human interaction with cats',
#                'Cat anatomy',
#                'Cat senses',
#                'Cultural depictions of cats'],
#               ['https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/Human_interaction_with_cats',
#                'https://en.wikipedia.org/wiki/Cat_anatomy',
#                'https://en.wikipedia.org/wiki/Cat_senses',
#                'https://en.wikipedia.org/wiki/Cultural_depictions_of_cats'],
#               [0.081612281501293182,
#                0.074896320700645447,
#                0.073116526007652283,
#                0.0577576644718647,
#                0.056635111570358276]],
#              'Walter the Farting Dog': [['Walter the Farting Dog',
#                'Walter the Farting Dog',
#                'Walter the Farting Dog',
#                'Walter the Farting Dog',
#                'Walter the Farting Dog'],
#               ['https://en.wikipedia.org/wiki/Walter_the_Farting_Dog',
#                'https://en.wikipedia.org/wiki/Walter_the_Farting_Dog',
#                'https://en.wikipedia.org/wiki/Walter_the_Farting_Dog',
#                'https://en.wikipedia.org/wiki/Walter_the_Farting_Dog',
#                'https://en.wikipedia.org/wiki/Walter_the_Farting_Dog'],
#               ['The Ten Commandments of Dog Ownership',
#                'Dog',
#                'Cat',
#                'My Life in Dog Years',
#                'Dog meat'],
#               ['https://en.wikipedia.org/wiki/The_Ten_Commandments_of_Dog_Ownership',
#                'https://en.wikipedia.org/wiki/Dog',
#                'https://en.wikipedia.org/wiki/Cat',
#                'https://en.wikipedia.org/wiki/My_Life_in_Dog_Years',
#                'https://en.wikipedia.org/wiki/Dog_meat'],
#               [0.16809237003326416,
#                0.097404368221759796,
#                0.083355739712715149,
#                0.081817664206027985,
#                0.067136391997337341]]})

# %%
# make dataframe with (1) article title, (2) url, (3) list of similar articles, (4) list of urls for similar articles, 
# (5) list of similarity scores
df_sim = pd.DataFrame.from_dict(lsi_similarity_matrix, orient='index')
df_sim.columns = ['title','url','similar_titles', 'urls', 'scores']
df_sim.head()
# Out:
#                                          title  \
# Kennel                                [Kennel]
# Cynology                            [Cynology]
# Pack (canine)                  [Pack (canine)]
# Rare breed (dog)            [Rare breed (dog)]
# Dogs in ancient China  [Dogs in ancient China]
#
#                                                                      url  \
# Kennel                            [https://en.wikipedia.org/wiki/Kennel]
# Cynology                        [https://en.wikipedia.org/wiki/Cynology]
# Pack (canine)              [https://en.wikipedia.org/wiki/Pack_(canine)]
# Rare breed (dog)        [https://en.wikipedia.org/wiki/Rare_breed_(dog)]
# Dogs in ancient China  [https://en.wikipedia.org/wiki/Dogs_in_ancient...
#
#                                                           similar_titles  \
# Kennel                 [Cattery, Indian National Kennel Club, Breed t...
# Cynology               [Dog, Breed type (dog), Cat training, Pussy, F...
# Pack (canine)          [Canid hybrid, Dog, Origin of the domestic dog...
# Rare breed (dog)       [Breed type (dog), Lists of dogs, Dog, Dog bit...
# Dogs in ancient China  [Dogs in Mesoamerica, Dog, Origin of the domes...
#
#                                                                     urls  \
# Kennel                 [https://en.wikipedia.org/wiki/Cattery, https:...
# Cynology               [https://en.wikipedia.org/wiki/Dog, https://en...
# Pack (canine)          [https://en.wikipedia.org/wiki/Canid_hybrid, h...
# Rare breed (dog)       [https://en.wikipedia.org/wiki/Breed_type_(dog...
# Dogs in ancient China  [https://en.wikipedia.org/wiki/Dogs_in_Mesoame...
#
#                                                                   scores
# Kennel                 [0.335962384939, 0.27727752924, 0.172500282526...
# Cynology               [0.143377020955, 0.127784788609, 0.12467522919...
# Pack (canine)          [0.270516097546, 0.224993467331, 0.21706835925...
# Rare breed (dog)       [0.329889953136, 0.166610077024, 0.16474558413...
# Dogs in ancient China  [0.203201308846, 0.200637221336, 0.20002917945...

# %%
df_sim.to_csv('df_sim_lsi.csv')

# %%
print_similar_articles(word_data_df, lsi_matsim, 10)

# %%
def make_rp_similarity_matrix(tfidf_corpus, dictionary):
    """
    construct RP (random projections) model on Tfidf-transformed corpus, print model topics, 
    return similarity matrix.
    """
    # construct model
    rp = models.RpModel(corpus=tfidf_corpus, id2word=dictionary, num_topics=200)
    rp.save('wiki.rp_model')
    # create similarity matrix
    matsim = similarities.MatrixSimilarity(rp[tfidf_corpus], num_best=6)
    return(matsim)

# %%
rp_matsim = make_rp_similarity_matrix(tfidf[corpus], dictionary)
print_similar_articles(word_data_df, rp_matsim, 10)
