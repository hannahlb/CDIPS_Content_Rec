# %% [markdown]
# Using minidom to parse XML
#
# ref: https://www.tutorialspoint.com/python/python_xml_processing.htm

# %%
import sys, os
from xml.dom import minidom

# %%
os.chdir('data')
xmlfile = 'Wikipedia-20170717213140.xml'

# %%
xmldoc = minidom.parse(xmlfile)
# collect title, id, text of each wikipage
titlelist = xmldoc.getElementsByTagName('title')
idlist = xmldoc.getElementsByTagName('id')
textlist = xmldoc.getElementsByTagName('text')

# %%
# number of wiki articles in our file
print(len(titlelist))

# %%
# print article titles
for item in titlelist:
    print(item.childNodes[0].data)

# %%
# print text of first article
print(textlist[0].childNodes[0].data)

# %% [markdown]
# Compare this with the original XML:
#
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# Now let's use nltk to tokenize and clean up the text

# %%
import nltk

# %%
tokenizer = nltk.RegexpTokenizer(r'\w+')
text = textlist[0].childNodes[0].data.lower()
ttext = tokenizer.tokenize(text)
print(ttext)
# Out:
# ['cat', 'main', 'conformation', 'show', 'show', 'dog', 'portal', 'dogs', 'this', 'is', 'an', 'automatically', 'collected', 'list', 'of', 'articles', 'related', 'to', 'showing', 'dogs', 'for', 'their', 'appearance', 'in', 'conformation', 'show', 's', 'category', 'dogs', 'shows', 'and', 'showing', 'category', 'competitions', 'category', 'animal', 'shows', 'dog']

# %% [markdown]
# The above article was a category. Lets see what happens for a true article with links, etc in the text. Looking at the list of titles, the 9th title, 'Kennel', looks like an article

# %%
# print text of 9th article
text = textlist[8].childNodes[0].data.lower()
print(text)
ttext = tokenizer.tokenize(text)
print(ttext)

# %% [markdown]
# Use topic modeling to see how similar articles are:
#
# refs: http://www.datasciencebytes.com/bytes/2014/12/30/topic-modeling-of-shakespeare-characters/
#     http://www.datasciencebytes.com/bytes/2014/11/20/using-topic-modeling-to-find-related-blog-posts/

# %%
import pandas as pd
from collections import defaultdict
from gensim import corpora, models, similarities
# Out:
# C:\Users\melanie\Anaconda3\envs\cdips2017\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# organize articles into a dataframe...not sure if we need to exclude articles of short length? 
min_length = 50  # minimum word count
word_data = [(title.childNodes[0].data, tokenizer.tokenize(text.childNodes[0].data.lower()))
             for title, text in zip(titlelist, textlist)
             if len(tokenizer.tokenize(text.childNodes[0].data.lower())) >= min_length]
word_data_df = pd.DataFrame(word_data, columns=['title', 'words'])
word_data_df.to_csv('word_data_df.csv')
word_data_df.head()
# Out:
#                  title                                              words
# 0               Kennel  [about, shelter, for, dogs, and, cats, for, th...
# 1             Cynology  [cynology, ipac, en, s, ᵻ, ˈ, n, ɒ, l, ə, dʒ, ...
# 2  Category:Dog breeds  [category, diffuse, cat, main, dog, breed, lis...
# 3        Pack (canine)  [other, uses, wolfpack, disambiguation, image,...
# 4     Rare breed (dog)  [for, a, list, of, rare, dog, breeds, category...

# %%
word_data_df.tail()
# Out:
#                       title                                              words
# 104                     Cat  [about, the, cat, species, that, is, commonly,...
# 105                Cat bite  [infobox, disease, name, cat, bite, image, cat...
# 106  Ancylostoma tubaeforme  [italic, title, taxobox, image, name, ancylost...
# 107         Feline diseases  [further, feline, zoonosis, see, cat, health, ...
# 108   International Cat Day  [infobox, holiday, holiday_name, international...

# %%
# make gensim dictionary
line_list = word_data_df['words'].values
dictionary = corpora.Dictionary(line_list)
# filter dictionary to remove stopwords and words occurring < min_count times
# need to run nltk.download() -> 3 GB downloaded into C:\Users\melanie\AppData\Roaming\nltk_data
stop_words = nltk.corpus.stopwords.words('english') 
min_count = 2
stop_ids = [dictionary.token2id[word] for word in stop_words
            if word in dictionary.token2id]
rare_ids = [id for id, freq in dictionary.dfs.items()
            if freq < min_count]
dictionary.filter_tokens(stop_ids + rare_ids)
dictionary.compactify()

# %%
# convert dictionary to a bag of words, tuples of word indices and word counts
corpus = [dictionary.doc2bow(words) for words in line_list]

# %%
# serialize to avoid having to reload the corpus
corpora.mmcorpus.MmCorpus.serialize('wiki.mm', corpus) # we should build model, then serialize the model
# initialize transformation on input data with TF-IDF
# the TF-IDF model converts raw word counts to a value more indicative of the importance of each word (offsets word count with how often a word occurs in entire corpus)
tfidf = models.TfidfModel(corpus)

# %%
# construct model
lsi = models.lsimodel.LsiModel(corpus=tfidf[corpus], id2word=dictionary)
lsi.save('wiki.lsi')
for i, topic in enumerate(lsi.print_topics(5)[:3]):
    print('Topic: ', format(i))
    print(str(topic).replace(' + ', '\n')) 
    print('')
# Out:
# Topic:  0
# (0, '0.320*"cat"
# 0.234*"cats"
# 0.187*"dog"
# 0.158*"journal"
# 0.122*"ref"
# 0.112*"breeds"
# 0.105*"meat"
# 0.104*"name"
# 0.087*"doi"
# 0.086*"cite"')
#
# Topic:  1
# (1, '-0.669*"bailys"
# -0.285*"hunt"
# -0.278*"foxhounds"
# -0.236*"directory"
# -0.233*"england"
# -0.181*"harriers"
# -0.173*"beagles"
# -0.154*"packs"
# -0.145*"hunting"
# -0.138*"liams"')
#
# Topic:  2
# (2, '0.358*"cat"
# -0.354*"dog"
# -0.320*"breeds"
# 0.255*"cats"
# -0.238*"breed"
# 0.213*"cafe"
# -0.180*"list"
# -0.143*"kennel"
# -0.119*"dogs"
# -0.111*"types"')

# %% [markdown]
# Analysis of article topics
#
# ref: http://www.datasciencebytes.com/bytes/2014/12/31/analysis-of-shakespeare-character-speech-topics/

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from pprint import pprint

# %%
titles = word_data_df['title']

# %%
# use gensim to create similarity matrix
matsim = similarities.MatrixSimilarity(lsi[tfidf[corpus]], num_best=6)

# %%
# for the first 10 articles, print most similar articles and their similarity scores
for sims in list(matsim)[:10]:
    title_index = sims[0][0]
    print(titles[title_index]) 
    for other_title_index, score in sims[1:]:
        print('\t', titles[other_title_index], ' ', score)
# Out:
# Kennel
# 	 Cattery   0.336789280176
# 	 Indian National Kennel Club   0.27208802104
# 	 Breed type (dog)   0.163299113512
# 	 Lists of dogs   0.136161088943
# 	 Dog World (newspaper)   0.132600843906
# Cynology
# 	 Dog   0.148348629475
# 	 Cat training   0.126969367266
# 	 Breed type (dog)   0.125285759568
# 	 Pussy   0.122592501342
# 	 Felinology   0.112518906593
# Category:Dog breeds
# 	 Category:Dog types   0.467604964972
# 	 Category:Cat breeds   0.392773061991
# 	 Lists of dogs   0.368836134672
# 	 Rare breed (dog)   0.352223396301
# 	 Breed type (dog)   0.269845068455
# Pack (canine)
# 	 Canid hybrid   0.28900963068
# 	 Dog   0.239152625203
# 	 Origin of the domestic dog   0.230222508311
# 	 Canine reproduction   0.170482933521
# 	 Cat   0.117765501142
# Rare breed (dog)
# 	 Category:Dog breeds   0.352223396301
# 	 Breed type (dog)   0.300218075514
# 	 Category:Cat breeds   0.257960915565
# 	 Category:Dog types   0.241543009877
# 	 Category:Dog stubs   0.178791120648
# Category:Dog types
# 	 Category:Dog breeds   0.467604964972
# 	 Lists of dogs   0.354141145945
# 	 Category:Cat breeds   0.289088636637
# 	 Rare breed (dog)   0.241543009877
# 	 Breed type (dog)   0.192496955395
# Dogs in ancient China
# 	 Origin of the domestic dog   0.202551946044
# 	 Dogs in Mesoamerica   0.201422899961
# 	 Dog   0.199515774846
# 	 Dog meat   0.188854709268
# 	 Panhu   0.181942775846
# Dog biscuit
# 	 Dog food   0.256881296635
# 	 Dog meat   0.163758203387
# 	 Cat meat   0.139586225152
# 	 Dog daycare   0.135974690318
# 	 Dog   0.10498817265
# Breed type (dog)
# 	 Rare breed (dog)   0.300218075514
# 	 Category:Dog breeds   0.269845068455
# 	 Category:Dog stubs   0.231903657317
# 	 Dog World (newspaper)   0.197868898511
# 	 Indian National Kennel Club   0.194945722818
# Canid hybrid
# 	 Origin of the domestic dog   0.412205547094
# 	 Dog   0.373384952545
# 	 Interbreeding of dingoes with other domestic dogs   0.357040077448
# 	 Pack (canine)   0.28900963068
# 	 Cat   0.186847895384

# %%
# project first article into the first 10 dimensions, i.e. those containing the most information 
lsi[tfidf[corpus[0]]][:10]
# Out:
# [(0, 0.16743241036846326),
#  (1, -0.0025212116226713439),
#  (2, -0.14403877347169733),
#  (3, 0.16094228202846125),
#  (4, -0.010223756925320465),
#  (5, 0.063219978813572081),
#  (6, -0.0030777479504244284),
#  (7, 0.041884158868879175),
#  (8, -0.11407882660747753),
#  (9, 0.2608778705973635)]

# %%
# plot projection of articles onto 2 axes/topics defined by the LSI model; print 10 most impt words above plot
def format_topic_coeffs(topic):
    """Return a list of coefficent, word tuples with coefficent truncated to 
    3 decimal places.
    """
    return [(format(coeff), word) for coeff, word in topic]

def plot_axes(x=0, y=1, model=lsi, corpus=corpus, 
              tfidf=tfidf, titles=titles):
    """Plot each article title according to the projection of its text 
    into the given x and y topic axes of model.
    
    :param x: the index of the x axis to plot
    :param y: the index of the y axis to plot
    :param model: the gensim model to project into
    :param corpus: the gensim corpus of documents
    :param tfidf: a tfidf model for converting documents into tfidf space
    :param titles: a list of article titles
    """
    x_data = defaultdict(list) 
    y_data = defaultdict(list) 
    arts = defaultdict(list)  
    print('x topic:')
    pprint(format_topic_coeffs(model.show_topic(x)))
    print('')
    print('y topic:') 
    pprint(format_topic_coeffs(model.show_topic(y)))
    for title, doc in zip(titles, corpus):
        x_data[0].append((model[tfidf[doc]][x][1]))
        y_data[0].append((model[tfidf[doc]][y][1]))
        arts[0].append(title)
    plt.figure(figsize=(10, 10))
    ax = plt.gca()
    plt.scatter(x_data[0], y_data[0], s=40)
    for art, x, y in zip(arts[0], x_data[0], y_data[0]):
        ax.annotate(str(art), xy=(x, y), xycoords='data', xytext=(1, 1), 
        textcoords='offset points', size=10)

# %%
# looks like y-axis separates articles about hounds/dog hunting in the british commonwealth from all other articles
plot_axes(x=0, y=1)
# Out:
# x topic:
# [('cat', 0.32045196150693139),
#  ('cats', 0.23430912558903264),
#  ('dog', 0.18738854784288911),
#  ('journal', 0.15797559981789747),
#  ('ref', 0.12203390827197887),
#  ('breeds', 0.11236879781885681),
#  ('meat', 0.10482193919118944),
#  ('name', 0.10368914522505668),
#  ('doi', 0.086582403492137902),
#  ('cite', 0.086302059618646274)]
#
# y topic:
# [('bailys', -0.66850336040702696),
#  ('hunt', -0.28535311752168718),
#  ('foxhounds', -0.27769267421520094),
#  ('directory', -0.23551655958147208),
#  ('england', -0.23288404156131778),
#  ('harriers', -0.18107348203698614),
#  ('beagles', -0.17286629536658321),
#  ('packs', -0.15408628694697721),
#  ('hunting', -0.14491214374716813),
#  ('liams', -0.13802418865864674)]

# %%
# x-axis separates dogs and cats
plot_axes(x=2, y=3)
# Out:
# x topic:
# [('cat', 0.35761512040723425),
#  ('dog', -0.35416603600411578),
#  ('breeds', -0.31989452028568094),
#  ('cats', 0.25537172714440759),
#  ('breed', -0.23764695268192843),
#  ('cafe', 0.21327069694136369),
#  ('list', -0.17951532342442836),
#  ('kennel', -0.14302950744883419),
#  ('dogs', -0.11928844044224299),
#  ('types', -0.1113512184843431)]
#
# y topic:
# [('breeds', 0.39203060217748226),
#  ('cat', 0.31559320082231462),
#  ('cafe', 0.27791399733317607),
#  ('breed', 0.2329164817751429),
#  ('list', 0.19059417431397815),
#  ('types', 0.17361266855283733),
#  ('bites', -0.12374232977797563),
#  ('bite', -0.12103199779181426),
#  ('café', 0.11048625390477416),
#  ('kennel', 0.10865498789700694)]

# %%
plot_axes(x=4, y=5)
# Out:
# x topic:
# [('meat', -0.34065147359930709),
#  ('bites', 0.23502053915483181),
#  ('bite', 0.2097959836522843),
#  ('festival', -0.17139187414218068),
#  ('china', -0.16918472087299744),
#  ('breeds', 0.1629476331534096),
#  ('rabies', 0.15261651941750592),
#  ('cdc', 0.14589852965957745),
#  ('cafe', -0.12148431723943387),
#  ('infection', 0.11491490668800537)]
#
# y topic:
# [('cafe', 0.40911630665178861),
#  ('bite', 0.18759876247540322),
#  ('bites', 0.18001279819318483),
#  ('wagging', 0.16299408214046382),
#  ('café', 0.16073033161474687),
#  ('wolf', -0.14106859913977807),
#  ('meat', 0.11932616766932491),
#  ('rabies', 0.11801347754561006),
#  ('dog', 0.1177250654283188),
#  ('2017', 0.10719939973394654)]
