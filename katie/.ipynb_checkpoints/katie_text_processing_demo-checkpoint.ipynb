# %%
import os, sys
import re
import nltk
import gensim
import pandas as pd
import xml.etree.ElementTree as ET
from collections import defaultdict
from gensim import corpora
sys.path.insert(0, '../scripts')
from WikiPage import WikiPage

# %%
os.chdir('../data')
xmlfile = 'Wikipedia-dog.xml'

# %%
tree = ET.parse(xmlfile)
root = tree.getroot()

# %%
test_index = 100
test = WikiPage(root[test_index])

# %%
test.data
# Out:
#                                               website          title  \
# 17701542  https://en.wikipedia.org/wiki/KattenKabinet  KattenKabinet
#
#          page_type                                           text_raw
# 17701542   article  [[File:Cat Cabinet face Amsterdam-Photo by Pej...

# %%
def clean_raw_text(text_raw, searchstr):
    m = re.search(searchstr, text_raw)
    if m:
        text_raw = re.sub(searchstr, ' ', text_raw)
        text_raw = clean_raw_text(text_raw, searchstr)
    return text_raw

# %%
print(test.text_raw[:1000])
# Out:
# [[File:Cat Cabinet face Amsterdam-Photo by Pejman Akbarzadeh Persian Dutch Network.jpg|thumb|The KattenKabinet in [[Amsterdam]]]]
#
# The '''KattenKabinet''' ("Cat Cabinet") is an art museum in [[Amsterdam]] devoted to works depicting [[cat]]s. The museum collection includes paintings, drawings, sculptures and other works of art by [[Pablo Picasso]], [[Rembrandt]], [[Henri de Toulouse-Lautrec]], [[Guillaume Cornelis van Beverloo|Corneille]], [[Sal Meijer]], [[Théophile Steinlen]], and [[Jože Ciuha]], among others.
#
# The museum is housed in a canalside building at [[Herengracht]] 497, in the grand ''[[Gouden Bocht]]'' ("Golden Bend") of this canal. The owner lives on the second floor of the building with his family. There are some cats in the museum as well.
#
# == History ==
# The house and the adjacent building at Herengracht 499 were built in 1667 for the patrician brothers Willem and Adriaen van Loon. Through the luck of the draw, Willem was given the house at number 497. Later, the house w

# %%
clean_raw_text(test.text_raw, '[\(\[].*?[\)\]]')
# Out:
# " ]]]\n\nThe '''KattenKabinet'''   is an art museum in  ] devoted to works depicting  ]s. The museum collection includes paintings, drawings, sculptures and other works of art by  ],  ],  ],  ],  ],  ], and  ], among others.\n\nThe museum is housed in a canalside building at  ] 497, in the grand '' ]''   of this canal. The owner lives on the second floor of the building with his family. There are some cats in the museum as well.\n\n== History == \nThe house and the adjacent building at Herengracht 499 were built in 1667 for the patrician brothers Willem and Adriaen van Loon. Through the luck of the draw, Willem was given the house at number 497. Later, the house was inhabited by Amsterdam mayor  ] and Amsterdam pensionary  ], among others.  ] visited Van Berckel at the house during his time as U.S. ambassador to the Dutch republic.\n\nIn 1985, the building was restored, and in 1990 the museum was founded by Bob Meijer in memory of his red tomcat John Pierpont Morgan  ]).\n\nThe museum served as filming location for '' ]'' in 2004.<ref>{{cite web|title=Ocean Twelve - Production notes - About the production|url=http://www.cinemareview.com/production.asp?prodid=2807|publisher=CinemaReview.com|accessdate=December 1, 2013}}</ref>\n\n== Gallery ==\n<gallery widths=150 heights=150>\nFile:Cat-Cabinet-Amsterdam-Photo by Pejman Akbarzadeh Persian Dutch Network.jpg|Inside the KattenKabinet\nFile:Amsterdam - KattenKabinet - 0363.jpg|Restored 17th-century ceiling painting\n</gallery>\n\n==References==\n{{Reflist}}\n\n==External links==\n{{Commonscat}}\n{{Rijksmonument|1662}}\n*  \n\n{{Coord|52|21|56|N|4|53|29.5|E|region:NL_type:landmark|display=title}}\n\n{{Cat themed museums and galleries}}\n ]\n ]\n ]\n ]\n ]\n ]"

# %%
text = re.sub(r'[^\w]', ' ', test.text_raw)
text
# Out:
# '  File Cat Cabinet face Amsterdam Photo by Pejman Akbarzadeh Persian Dutch Network jpg thumb The KattenKabinet in   Amsterdam      The    KattenKabinet      Cat Cabinet   is an art museum in   Amsterdam   devoted to works depicting   cat  s  The museum collection includes paintings  drawings  sculptures and other works of art by   Pablo Picasso      Rembrandt      Henri de Toulouse Lautrec      Guillaume Cornelis van Beverloo Corneille      Sal Meijer      Théophile Steinlen    and   Jože Ciuha    among others   The museum is housed in a canalside building at   Herengracht   497  in the grand     Gouden Bocht       Golden Bend   of this canal  The owner lives on the second floor of the building with his family  There are some cats in the museum as well      History     The house and the adjacent building at Herengracht 499 were built in 1667 for the patrician brothers Willem and Adriaen van Loon  Through the luck of the draw  Willem was given the house at number 497  Later  the house was inhabited by Amsterdam mayor   Jan Calkoen   and Amsterdam pensionary   Engelbert François van Berckel    among others    John Adams   visited Van Berckel at the house during his time as U S  ambassador to the Dutch republic   In 1985  the building was restored  and in 1990 the museum was founded by Bob Meijer in memory of his red tomcat John Pierpont Morgan  named after the American banker   J  P  Morgan      The museum served as filming location for     Ocean s Twelve     in 2004  ref   cite web title Ocean Twelve   Production notes   About the production url http   www cinemareview com production asp prodid 2807 publisher CinemaReview com accessdate December 1  2013    ref      Gallery     gallery widths 150 heights 150  File Cat Cabinet Amsterdam Photo by Pejman Akbarzadeh Persian Dutch Network jpg Inside the KattenKabinet File Amsterdam   KattenKabinet   0363 jpg Restored 17th century ceiling painting   gallery     References     Reflist      External links     Commonscat     Rijksmonument 1662      http   www kattenkabinet nl Website of the KattenKabinet     Coord 52 21 56 N 4 53 29 5 E region NL_type landmark display title      Cat themed museums and galleries     Category Museums in Amsterdam     Category Cats     Category Museums established in 1990     Category Art museums and galleries in the Netherlands     Category 1990 establishments in the Netherlands     Category Cats in popular culture  '

# %%
tokenizer = nltk.RegexpTokenizer(r'\w+')
ttext = tokenizer.tokenize(test.text_raw)
print(ttext)
# Out:
# ['File', 'Cat', 'Cabinet', 'face', 'Amsterdam', 'Photo', 'by', 'Pejman', 'Akbarzadeh', 'Persian', 'Dutch', 'Network', 'jpg', 'thumb', 'The', 'KattenKabinet', 'in', 'Amsterdam', 'The', 'KattenKabinet', 'Cat', 'Cabinet', 'is', 'an', 'art', 'museum', 'in', 'Amsterdam', 'devoted', 'to', 'works', 'depicting', 'cat', 's', 'The', 'museum', 'collection', 'includes', 'paintings', 'drawings', 'sculptures', 'and', 'other', 'works', 'of', 'art', 'by', 'Pablo', 'Picasso', 'Rembrandt', 'Henri', 'de', 'Toulouse', 'Lautrec', 'Guillaume', 'Cornelis', 'van', 'Beverloo', 'Corneille', 'Sal', 'Meijer', 'Théophile', 'Steinlen', 'and', 'Jože', 'Ciuha', 'among', 'others', 'The', 'museum', 'is', 'housed', 'in', 'a', 'canalside', 'building', 'at', 'Herengracht', '497', 'in', 'the', 'grand', 'Gouden', 'Bocht', 'Golden', 'Bend', 'of', 'this', 'canal', 'The', 'owner', 'lives', 'on', 'the', 'second', 'floor', 'of', 'the', 'building', 'with', 'his', 'family', 'There', 'are', 'some', 'cats', 'in', 'the', 'museum', 'as', 'well', 'History', 'The', 'house', 'and', 'the', 'adjacent', 'building', 'at', 'Herengracht', '499', 'were', 'built', 'in', '1667', 'for', 'the', 'patrician', 'brothers', 'Willem', 'and', 'Adriaen', 'van', 'Loon', 'Through', 'the', 'luck', 'of', 'the', 'draw', 'Willem', 'was', 'given', 'the', 'house', 'at', 'number', '497', 'Later', 'the', 'house', 'was', 'inhabited', 'by', 'Amsterdam', 'mayor', 'Jan', 'Calkoen', 'and', 'Amsterdam', 'pensionary', 'Engelbert', 'François', 'van', 'Berckel', 'among', 'others', 'John', 'Adams', 'visited', 'Van', 'Berckel', 'at', 'the', 'house', 'during', 'his', 'time', 'as', 'U', 'S', 'ambassador', 'to', 'the', 'Dutch', 'republic', 'In', '1985', 'the', 'building', 'was', 'restored', 'and', 'in', '1990', 'the', 'museum', 'was', 'founded', 'by', 'Bob', 'Meijer', 'in', 'memory', 'of', 'his', 'red', 'tomcat', 'John', 'Pierpont', 'Morgan', 'named', 'after', 'the', 'American', 'banker', 'J', 'P', 'Morgan', 'The', 'museum', 'served', 'as', 'filming', 'location', 'for', 'Ocean', 's', 'Twelve', 'in', '2004', 'ref', 'cite', 'web', 'title', 'Ocean', 'Twelve', 'Production', 'notes', 'About', 'the', 'production', 'url', 'http', 'www', 'cinemareview', 'com', 'production', 'asp', 'prodid', '2807', 'publisher', 'CinemaReview', 'com', 'accessdate', 'December', '1', '2013', 'ref', 'Gallery', 'gallery', 'widths', '150', 'heights', '150', 'File', 'Cat', 'Cabinet', 'Amsterdam', 'Photo', 'by', 'Pejman', 'Akbarzadeh', 'Persian', 'Dutch', 'Network', 'jpg', 'Inside', 'the', 'KattenKabinet', 'File', 'Amsterdam', 'KattenKabinet', '0363', 'jpg', 'Restored', '17th', 'century', 'ceiling', 'painting', 'gallery', 'References', 'Reflist', 'External', 'links', 'Commonscat', 'Rijksmonument', '1662', 'http', 'www', 'kattenkabinet', 'nl', 'Website', 'of', 'the', 'KattenKabinet', 'Coord', '52', '21', '56', 'N', '4', '53', '29', '5', 'E', 'region', 'NL_type', 'landmark', 'display', 'title', 'Cat', 'themed', 'museums', 'and', 'galleries', 'Category', 'Museums', 'in', 'Amsterdam', 'Category', 'Cats', 'Category', 'Museums', 'established', 'in', '1990', 'Category', 'Art', 'museums', 'and', 'galleries', 'in', 'the', 'Netherlands', 'Category', '1990', 'establishments', 'in', 'the', 'Netherlands', 'Category', 'Cats', 'in', 'popular', 'culture']

# %%
df = pd.read_csv('../data/Wikipedia-dog.csv', index_col=0)

# %%
df.head()
# Out:
#                                                   website  \
# 970284  https://en.wikipedia.org/wiki/Category:Dog_sho...
# 972913  https://en.wikipedia.org/wiki/Category:Dog_health
# 970251  https://en.wikipedia.org/wiki/Category:Dog_org...
# 729436  https://en.wikipedia.org/wiki/Category:Dog_sports
# 978163  https://en.wikipedia.org/wiki/Category:Dogs_as...
#
#                                  title page_type  \
# 970284  Category:Dog shows and showing  category
# 972913             Category:Dog health  category
# 970251      Category:Dog organizations  category
# 729436             Category:Dog sports  category
# 978163           Category:Dogs as pets  category
#
#                                                  text_raw
# 970284  {{Cat main|Conformation show|Show dog}}\n{{por...
# 972913  This is a collection of articles about the hea...
# 970251  This is an automatically collected list of art...
# 729436  This is an automatically accumulated list of a...
# 978163  [[Category:Dogs|Pets]]\n[[Category:Mammals as ...

# %%
documents = list(df.text_raw.values)
documents[0]
# Out:
# '{{Cat main|Conformation show|Show dog}}\n{{portal|Dogs}}\nThis is an automatically collected list of articles related to showing dogs for their appearance in [[conformation show]]s.\n\n[[Category:Dogs|Shows and showing]]\n[[Category:Competitions]]\n[[Category:Animal shows| Dog]]'

# %%
#nltk.download()

# %%
stoplist = set(nltk.corpus.stopwords.words('english'))

# %%
texts = [[word for word in re.sub(r'[^\w]', ' ', document.lower()).split() \
          if word not in stoplist] \
         for document in documents]

# %%
frequency = defaultdict(int)

# %%
for text in texts:
     for token in text:
         frequency[token] += 1

# %%
texts = [[token for token in text if frequency[token] > 1]
          for text in texts]

# %%
dictionary = corpora.Dictionary(texts)
#dictionary.save('/tmp/wikipedia-dog.dict')  # store the dictionary, for future reference
print(dictionary)
print(dictionary.token2id)
# Out:
# Dictionary(12988 unique tokens: ['cat', 'main', 'conformation', 'show', 'dog']...)
# {'cat': 0, 'main': 1, 'conformation': 2, 'show': 3, 'dog': 4, 'portal': 5, 'dogs': 6, 'this': 7, 'is': 8, 'an': 9, 'automatically': 10, 'collected': 11, 'list': 12, 'articles': 13, 'related': 14, 'showing': 15, 'their': 16, 'appearance': 17, 's': 18, 'category': 19, 'shows': 20, 'competitions': 21, 'animal': 22, 'collection': 23, 'about': 24, 'health': 25, 'care': 26, 'primarily': 27, 'domestic': 28, 'includes': 29, 'medical': 30, 'conditions': 31, 'issues': 32, 'parasites': 33, 'surgical': 34, 'procedures': 35, 'similar': 36, 'topics': 37, 'commons': 38, 'mammal': 39, 'organizations': 40, 'sports': 41, 'involving': 42, 'animals': 43, 'sport': 44, 'pets': 45, 'mammals': 46, 'as': 47, 'equipment': 48, 'pet': 49, 'collects': 50, 'information': 51, 'how': 52, 'breed': 53, 'why': 54, 'people': 55, 'canine': 56, 'reproduction': 57, 'breeding': 58, 'see': 59, 'also': 60, 'domestication': 61, 'artificial': 62, 'selection': 63, 'monuments': 64, 'individual': 65, 'monu': 66, 'art': 67, 'shelter': 68, 'cats': 69, 'article': 70, 'shed': 71, 'built': 72, 'doghouse': 73, 'image': 74, 'kennel': 75, 'mason': 76, 'jpg': 77, 'thumb': 78, 'sits': 79, 'front': 80, 'typical': 81, 'panel': 82, 'structure': 83, 'or': 84, 'used': 85, 'kennels': 86, 'term': 87, 'means': 88, 'any': 89, 'building': 90, 'buildings': 91, 'property': 92, 'which': 93, 'are': 94, 'housed': 95, 'maintained': 96, 'though': 97, 'not': 98, 'all': 99, 'cases': 100, 'bred': 101, 'can': 102, 'be': 103, 'made': 104, 'out': 105, 'various': 106, 'materials': 107, 'most': 108, 'popular': 109, 'being': 110, 'wood': 111, 'formal': 112, 'establishment': 113, 'whether': 114, 'they': 115, 'actually': 116, 'separate': 117, 'garage': 118, 'state': 119, 'facility': 120, 'family': 121, 'dwelling': 122, 'licensed': 123, 'heavily': 124, 'regulated': 125, 'must': 126, 'follow': 127, 'relevant': 128, 'government': 129, 'legislation': 130, 'club': 131, 'members': 132, 'expected': 133, 'comply': 134, 'with': 135, 'general': 136, 'code': 137, 'ethics': 138, 'guidelines': 139, 'applicable': 140, 'concerned': 141, 'council': 142, 'may': 143, 'criteria': 144, 'met': 145, 'before': 146, 'registration': 147, 'papers': 148, 'puppies': 149, 'name': 150, 'associated': 151, 'each': 152, 'it': 153, 'first': 154, 'part': 155, 'registry': 156, 'registered': 157, 'names': 158, 'pedigreed': 159, 'was': 160, 'there': 161, 'likewise': 162, 'organization': 163, 'that': 164, 'registers': 165, 'exhibition': 166, 'purposes': 167, 'same': 168, 'society': 169, 'these': 170, 'affiliated': 171, 'one': 172, 'more': 173, 'registries': 174, 'whom': 175, 'have': 176, 'standards': 177, 'order': 178, 'able': 179, 'exhibit': 180, 'under': 181, 'boarding': 182, 'place': 183, 'where': 184, 'temporarily': 185, 'fee': 186, 'alternative': 187, 'using': 188, 'sitter': 189, 'although': 190, 'many': 191, 'stress': 192, 'placed': 193, 'on': 194, 'by': 195, 'put': 196, 'unfamiliar': 197, 'likely': 198, 'environment': 199, 'majority': 200, 'work': 201, 'reduce': 202, 'cn': 203, 'date': 204, 'august': 205, '2014': 206, 'offer': 207, 'play': 208, 'times': 209, 'get': 210, 'familiar': 211, 'objects': 212, 'such': 213, 'blankets': 214, 'toys': 215, 'from': 216, 'home': 217, 'permitted': 218, 'at': 219, 'similarly': 220, 'nowadays': 221, 'grooming': 222, 'training': 223, 'services': 224, 'addition': 225, 'idea': 226, 'owner': 227, 'stop': 228, 'shop': 229, 'three': 230, 'december': 231, '2012': 232, 'united': 233, 'states': 234, 'refer': 235, 'cattery': 236, 'catteries': 237, 'licensing': 238, 'agencies': 239, 'ref': 240, 'cite': 241, 'web': 242, 'url': 243, 'http': 244, 'www1': 245, 'co': 246, 'snohomish': 247, 'wa': 248, 'us': 249, 'departments': 250, 'htm': 251, 'title': 252, 'county': 253, 'official': 254, 'website': 255, 'do': 256, 'always': 257, 'differentiate': 258, 'between': 259, 'commercial': 260, 'other': 261, 'estimated': 262, '2008': 263, 'will': 264, 'spend': 265, '3': 266, '29': 267, 'billion': 268, '2007': 269, 'actual': 270, 'mar ...
